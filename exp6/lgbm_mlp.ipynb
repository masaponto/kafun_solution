# %%
import pandas as pd
import numpy as np

from typing import List, Tuple, Union, Dict

import matplotlib.pyplot as plt
import seaborn as sns
from scipy.signal import savgol_filter
import geocoder
import os
import random

import lightgbm as lgb
from lightgbm import LGBMRegressor
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

import datetime
import re
from sklearn.metrics import mean_absolute_error

from sklearn.model_selection import TimeSeriesSplit
from lightgbm import LGBMRegressor
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
class Config:
    train_path = "../input/train_v2.csv"
    test_path = "../input/test_v2.csv"
    sample_submission_path = "../input/sample_submission.csv"
    output_path = "../submission/"
    seed = 42
    n_splits = 2
    mlp=False

# %%
random.seed(Config.seed)
os.environ['PYTHONHASHSEED'] = str(Config.seed)
np.random.seed(Config.seed)

# %%
df_train = pd.read_csv(Config.train_path)
df_test = pd.read_csv(Config.test_path)

# %%
# 雪は花粉０そうなので0
df_train.loc[df_train["pollen_utsunomiya"] == -9998, "pollen_utsunomiya"] = 0
df_train.loc[df_train["pollen_chiba"] == -9998, "pollen_chiba"] = 0
df_train.loc[df_train["pollen_tokyo"] == -9998, "pollen_tokyo"] = 0

# %%
# spike 除去
def remove_spike(
    df, cols=["pollen_tokyo", "pollen_utsunomiya", "pollen_chiba"], th=3, span=24
):

    _df = df.copy()
    for col in cols:
        ewm_mean = _df[col].ewm(span=span).mean()
        ewm_std = _df[col].ewm(span=span).std()

        # _df.loc[(_df[col] - ewm_mean).abs() > ewm_std * th, col] = np.nan
        print(_df.loc[(_df[col] - ewm_mean) > ewm_std * th, "datetime"].shape)
        _df.loc[(_df[col] - ewm_mean) > ewm_std * th, col] = np.nan

    return _df

#df_train = remove_spike(df_train)

# %%
df_train[df_train.isna().any(axis=1)].shape
# Out:
# (0, 16)

# %%
df_train.head()
# Out:
#      datetime  precipitation_utsunomiya  precipitation_chiba  \
# 0  2017020101                       0.0                  0.0
# 1  2017020102                       0.0                  0.0
# 2  2017020103                       0.0                  0.0
# 3  2017020104                       0.0                  0.0
# 4  2017020105                       0.0                  0.0
#
#   precipitation_tokyo  temperature_utsunomiya temperature_chiba  \
# 0                 0.0                    -1.0               4.1
# 1                 0.0                    -1.1               4.2
# 2                 0.0                    -0.7               4.2
# 3                 0.0                    -1.1               4.4
# 4                 0.0                    -1.2               4.1
#
#   temperature_tokyo  winddirection_utsunomiya winddirection_chiba  \
# 0               2.9                        16                   1
# 1               2.6                         1                   1
# 2               2.4                         1                  15
# 3               1.8                         1                  15
# 4               1.5                         2                  14
#
#   winddirection_tokyo  windspeed_utsunomiya windspeed_chiba windspeed_tokyo  \
# 0                   2                   2.7             2.5             1.3
# 1                   1                   3.3             1.5             0.9
# 2                  16                   4.0             1.7             0.6
# 3                   1                   4.1             3.1             1.4
# 4                  14                   3.7             3.4             0.9
#
#    pollen_utsunomiya  pollen_chiba  pollen_tokyo
# 0                0.0           8.0           0.0
# 1                0.0          24.0           4.0
# 2                4.0          32.0          12.0
# 3                0.0          12.0           0.0
# 4                0.0          32.0           4.0

# %%
# 参考
# https://comp.probspace.com/competitions/pollen_counts/discussions/kotrying-Post833da695e2f337e5a86f


df_train = df_train.replace("欠測", np.nan)


df_train["precipitation_tokyo"] = df_train["precipitation_tokyo"].astype(float)
df_train["temperature_chiba"] = df_train["temperature_chiba"].astype(float)
df_train["temperature_tokyo"] = df_train["temperature_tokyo"].astype(float)

df_train["winddirection_chiba"] = df_train["winddirection_chiba"].fillna(0)
df_train["winddirection_chiba"] = df_train["winddirection_chiba"].astype(int)
df_train["winddirection_tokyo"] = df_train["winddirection_tokyo"].fillna(0)
df_train["winddirection_tokyo"] = df_train["winddirection_tokyo"].astype(int)

df_train["windspeed_chiba"] = df_train["windspeed_chiba"].astype(float)
df_train["windspeed_tokyo"] = df_train["windspeed_tokyo"].astype(float)


lgb_imp = IterativeImputer(
    estimator=LGBMRegressor(random_state=Config.seed, n_estimators=1000),
    max_iter=10,
    initial_strategy="mean",
    imputation_order="ascending",
    verbose=-1,
    random_state=Config.seed,
)

df_train = pd.DataFrame(lgb_imp.fit_transform(df_train), columns=df_train.columns)

# %%
#df_test = df_test.replace("欠測", np.nan)

# %%
df_train[df_train.isna().any(axis=1)].shape
# Out:
# (0, 16)

# %%
# 型がfloatになってしまっているので、もどす。
df_train[["winddirection_chiba", "winddirection_tokyo", "winddirection_utsunomiya"]] = (
    df_train[["winddirection_chiba", "winddirection_tokyo", "winddirection_utsunomiya"]].round().astype(int)
)
df_train[
    [
        "precipitation_tokyo",
        "temperature_chiba",
        "temperature_tokyo",
        "windspeed_chiba",
        "windspeed_tokyo",
    ]
] = df_train[
    [
        "precipitation_tokyo",
        "temperature_chiba",
        "temperature_tokyo",
        "windspeed_chiba",
        "windspeed_tokyo",
    ]
].round(
    1
)
df_train["datetime"] = df_train["datetime"].astype(int)

# df_train[df_train.select_dtypes(object).columns] = df_train[df_train.select_dtypes(object).columns]
df_train.head(3)
# Out:
#      datetime  precipitation_utsunomiya  precipitation_chiba  \
# 0  2017020101                       0.0                  0.0
# 1  2017020102                       0.0                  0.0
# 2  2017020103                       0.0                  0.0
#
#    precipitation_tokyo  temperature_utsunomiya  temperature_chiba  \
# 0                  0.0                    -1.0                4.1
# 1                  0.0                    -1.1                4.2
# 2                  0.0                    -0.7                4.2
#
#    temperature_tokyo  winddirection_utsunomiya  winddirection_chiba  \
# 0                2.9                        16                    1
# 1                2.6                         1                    1
# 2                2.4                         1                   15
#
#    winddirection_tokyo  windspeed_utsunomiya  windspeed_chiba  \
# 0                    2                   2.7              2.5
# 1                    1                   3.3              1.5
# 2                   16                   4.0              1.7
#
#    windspeed_tokyo  pollen_utsunomiya  pollen_chiba  pollen_tokyo
# 0              1.3                0.0           8.0           0.0
# 1              0.9                0.0          24.0           4.0
# 2              0.6                4.0          32.0          12.0

# %%
loc_list = ["宇都宮市中央生涯学習センター", "千葉県環境研究センター", "東京都多摩小平保健所"]

utsunomiya = "utsunomiya"
chiba = "chiba"
tokyo = "tokyo"

key_list = [utsunomiya, chiba, tokyo]

LATLNG_DICT = {}

try:

    for i, key in zip(loc_list, key_list):
        loc = geocoder.osm(i, timeout=5.0)
        print(loc.latlng)
        print(loc.address)
        LATLNG_DICT[key] = tuple(loc.latlng)

    LOC_VECTOR_DICT = {
        (utsunomiya, tokyo): np.array(LATLNG_DICT[utsunomiya])
        - np.array(LATLNG_DICT[tokyo]),
        (utsunomiya, chiba): np.array(LATLNG_DICT[utsunomiya])
        - np.array(LATLNG_DICT[chiba]),
        (chiba, tokyo): np.array(LATLNG_DICT[chiba]) - np.array(LATLNG_DICT[tokyo]),
        (chiba, utsunomiya): np.array(LATLNG_DICT[chiba])
        - np.array(LATLNG_DICT[utsunomiya]),
        (tokyo, chiba): np.array(LATLNG_DICT[tokyo]) - np.array(LATLNG_DICT[chiba]),
        (tokyo, utsunomiya): np.array(LATLNG_DICT[tokyo])
        - np.array(LATLNG_DICT[utsunomiya]),
    }

    print(LATLNG_DICT)
    print(LOC_VECTOR_DICT)

except Exception as e:
    print(e)
    print("APIでのデータ取得に失敗したため、成功時に取得したデータを使います。")
    LATLNG_DICT = {
        "utsunomiya": (36.5594462, 139.88265145),
        "chiba": (35.633642, 140.077749),
        "tokyo": (35.7298652, 139.51664115548698),
    }
    LOC_VECTOR_DICT = {
        ("utsunomiya", "tokyo"): np.array([0.829581, 0.36601029]),
        ("utsunomiya", "chiba"): np.array([0.9258042, -0.19509755]),
        ("chiba", "tokyo"): np.array([-0.0962232, 0.56110784]),
        ("chiba", "utsunomiya"): np.array([-0.9258042, 0.19509755]),
        ("tokyo", "chiba"): np.array([0.0962232, -0.56110784]),
        ("tokyo", "utsunomiya"): np.array([-0.829581, -0.36601029]),
    }
# Out:
# [36.5594462, 139.88265145]
# 宇都宮市 中央生涯学習センター, 中央通り, 中央一丁目, 宇都宮市, 栃木県, 320-0802, 日本
# [35.633642, 140.077749]
# 千葉県環境研究センター, 海浜松風通り, 高浜五丁目, 美浜区, 千葉市, 千葉県, 261-0004, 日本
# [35.7298652, 139.51664115548698]
# 東京都多摩小平保健所, 青梅街道, 芝久保町, 小平市, 東京都, 188-0014, 日本
# {'utsunomiya': (36.5594462, 139.88265145), 'chiba': (35.633642, 140.077749), 'tokyo': (35.7298652, 139.51664115548698)}
# {('utsunomiya', 'tokyo'): array([0.829581  , 0.36601029]), ('utsunomiya', 'chiba'): array([ 0.9258042 , -0.19509755]), ('chiba', 'tokyo'): array([-0.0962232 ,  0.56110784]), ('chiba', 'utsunomiya'): array([-0.9258042 ,  0.19509755]), ('tokyo', 'chiba'): array([ 0.0962232 , -0.56110784]), ('tokyo', 'utsunomiya'): array([-0.829581  , -0.36601029])}

# %% [markdown]
# # Feature

# %%
# 時間
def to_datetime(time: datetime.datetime) -> datetime.datetime:
    time = str(time)
    try:
        time = datetime.datetime.strptime(time, "%Y%m%d%H")
    except ValueError:
        time = re.sub("24$", "23", time)
        time = datetime.datetime.strptime(time, "%Y%m%d%H")
        time += datetime.timedelta(hours=1)
    return time


def time_feat(df: pd.DataFrame) -> pd.DataFrame:
    df["datetime_dt"] = df["datetime"].apply(to_datetime)
    df["year"] = df["datetime_dt"].dt.year
    df["month"] = df["datetime_dt"].dt.month
    df["day"] = df["datetime_dt"].dt.day
    df["hour"] = df["datetime_dt"].dt.hour
    df["hour_sin"] = np.sin(df["datetime_dt"].dt.hour * (2 * np.pi / (24 + 1)))
    df["hour_cos"] = np.cos(df["datetime_dt"].dt.hour * (2 * np.pi / (24 + 1)))
    df["weekday"] = df["datetime_dt"].dt.weekday
    df["day_of_year"] = df["datetime_dt"].dt.dayofyear
    df["day_sin"] = np.sin(df["day_of_year"] * (2 * np.pi / (365 + 1)))
    df["day_cos"] = np.cos(df["day_of_year"] * (2 * np.pi / (365 + 1)))

    df["month_sin"] = np.sin(df["month"] * (2 * np.pi / (12 + 1)))
    df["month_cos"] = np.cos(df["month"] * (2 * np.pi / (12 + 1)))

    df["day_sin_sum_hour_sin"] = df["day_sin"] + df["hour_sin"]
    df["day_cos_sum_hour_cos"] = df["day_sin"] + df["hour_cos"]

    df["day_sin_sum_hour_sin_sum_month_sin"] = (
        df["day_sin"] + df["hour_sin"] + df["month_sin"]
    )
    df["day_cos_sum_hour_cos_sum_month_cos"] = (
        df["day_sin"] + df["hour_cos"] + df["month_cos"]
    )

    df["hour_sin_sum_month_sin"] = df["hour_sin"] + df["month_sin"]
    df["hour_cos_sum_month_cos"] = df["hour_cos"] + df["month_cos"]

    df["day_sin_mult_hour"] = df["day_sin"] * (1 + df["hour"] / 24)
    df["day_cos_mult_hour"] = df["day_cos"] * (1 + df["hour"] / 24)

    df["day_sin_mult_hour_mult_month"] = (
        df["day_sin"] * (1 + df["hour"] / 24) * (1 + df["month"] / 13)
    )
    df["day_cos_mult_hour_mult_month"] = (
        df["day_cos"] * (1 + df["hour"] / 24) * (1 + df["month"] / 13)
    )

    #     df["day_sin_mulit_hour_sin"] = df["hour_sin"] * df["day_sin"]
    #     df["day_sin_mulit_hour_cos"] = df["hour_cos"] * df["day_cos"]

    #     df["day_sin_sum_hour_sin"] = df["hour_sin"] + df["day_sin"]
    #     df["day_sin_sum_hour_cos"] = df["hour_cos"] + df["day_cos"]

    #     df["day_sin_mulit_hour_sin_mult_month"] = df["hour_sin"] * df["day_sin"] * (df["month"] / 12)
    #     df["day_sin_mulit_hour_cos_mult_month"] = df["hour_cos"] * df["day_cos"] * (df["month"] / 12)

    #     df["day_sin_sum_hour_sin_mult_month"] = df["hour_sin"] + df["day_sin"] * (df["month"] / 12)
    #     df["day_sin_sum_hour_cos_mult_month"] = df["hour_cos"] + df["day_cos"] * (df["month"] / 12)

    # for col in ["temperature_tokyo", "temperature_utsunomiya", "temperature_chiba"]:

    #     df[f"month_sin_mult_temperature_{col}"] = df[col] * df["month_sin"]
    #     df[f"month_cos_mult_temperature_{col}"] = df[col] * df["month_cos"]

    #     df[f"day_sin_sum_hour_sin_sum_month_sin_mult_temperature_{col}"] = df[col] * df["day_sin_sum_hour_sin_sum_month_sin"]
    #     df[f"day_sin_sum_hour_sin_sum_month_sin_mult_temperature_{col}"] = df[col] * df["day_sin_sum_hour_sin_sum_month_sin"]

    return df


# ラグ特徴/ローリング特徴量
def add_lag_feat(df: pd.DataFrame, feat: List[str], group: str) -> pd.DataFrame:
    outputs = [df]

    grp_df = df.groupby(group)  # year ごとにシフトする。 各年1~6月期間しかないのでこのようにする。

    for lag in [1, 2, 3, 4, 5]:
    #for lag in list(range(1, 25)):
        # shift
        outputs.append(grp_df[feat].shift(lag).add_prefix(f"shift{lag}_"))
        # diff
        outputs.append(grp_df[feat].diff(lag).add_prefix(f"diff{lag}_"))

    # rolling
    windows = [3] + [i * 24 for i in range(1, 10)]
    for window in windows:
        tmp_df = grp_df[feat].rolling(window, min_periods=1)
        tmp_df = tmp_df.mean().add_prefix(f"rolling{window}_mean_")
        outputs.append(tmp_df.reset_index(drop=True))

    _df = pd.concat(outputs, axis=1)
    return _df


def add_lag_feat_one_year(df: pd.DataFrame, feat: List[str]) -> pd.DataFrame:
    outputs = [df]
    prefix = "shift_one_year_"
    outputs.append(df[feat].shift(3600).add_prefix(prefix))

    df = pd.concat(outputs, axis=1)
    outputs = [df]
    cols = [f"{prefix}{col}" for col in feat]

    for window in [3] + [i * 24 for i in range(1, 10)]:
        outputs.append(
            df[cols].rolling(window, min_periods=1).mean().add_prefix(f"roll_{window}_")
        )

    df = pd.concat(outputs, axis=1)
    return df


# 集計特徴
def additional_encoding(
    train: pd.DataFrame, test: pd.DataFrame, cat_col: List[str], num_col: List[str]
) -> Tuple[pd.DataFrame, pd.DataFrame]:

    trdf = train.copy()
    tedf = test.copy()

    # Count Encoding
    for ccol in cat_col:
        encoder = trdf[(trdf["month"] == 4) & (trdf["day"] < 15)][ccol].value_counts()
        trdf[f"ce_{ccol}"] = trdf[ccol].map(encoder)
        tedf[f"ce_{ccol}"] = tedf[ccol].map(encoder)

    # Add Aggregate Features
    agg_cols = ["mean", "std", "min", "max"]
    for ccol in cat_col:
        for ncol in num_col:
            agg_df = trdf.groupby(ccol)[ncol].agg(agg_cols)
            agg_df["abs_mean"] = np.abs(agg_df["mean"])
            agg_df["min_max"] = agg_df["min"] * agg_df["max"]
            agg_df.columns = [f"{ccol}_{c}" for c in agg_df.columns]
            trdf = trdf.merge(agg_df, on=ccol, how="left")
            tedf = tedf.merge(agg_df, on=ccol, how="left")

    return trdf, tedf


def add_wind_direction_one_hot(df: pd.DataFrame) -> pd.DataFrame:

    cols = [
        "winddirection_utsunomiya",
        "winddirection_tokyo",
        "winddirection_chiba",
    ]

    num_wind_direction = 17

    dfs = []
    for col in cols:
        data = {f"{col}_one_hot_{i}": [] for i in range(num_wind_direction)}
        for x in df[col].astype(int):
            for i in range(num_wind_direction):
                if x == i:
                    data[f"{col}_one_hot_{i}"].append(1)
                else:
                    data[f"{col}_one_hot_{i}"].append(0)

        _df = pd.DataFrame(data)
        dfs.append(_df)

    return pd.concat([df] + dfs, axis=1)


def add_wind_direction_to_cos_sin(df: pd.DataFrame) -> pd.DataFrame:
    """
    {col} が 0：静穏 の場合 {col}_cos, {col}_sinには、欠損になる
    1：北北東
    2：北東
    3：東北東
    4：東
    5：東南東
    6：南東
    7：南南東
    8：南
    9：南南西
    10：南西
    11：西南西
    12：西
    13：西北西
    14：北西
    15：北北西
    16：北

    """
    df_origin = df.copy()

    direction_map = {
        1: 13,
        2: 14,
        3: 15,
        4: 0,
        5: 1,
        6: 2,
        7: 3,
        8: 4,
        9: 5,
        10: 6,
        11: 7,
        12: 8,
        13: 9,
        14: 10,
        15: 11,
        16: 12,
    }

    pref_list = [utsunomiya, tokyo, chiba]

    for col in [
        "winddirection_utsunomiya",
        "winddirection_tokyo",
        "winddirection_chiba",
    ]:

        _df = df_origin[[col]].copy()
        _df = _df.reset_index()
        _df = _df[_df[col] != 0].reset_index(drop=True)  # 0：静穏 は風の方向ではないので消す
        # _df[col] = _df[col] - 1  # 1 ~ 16 なので 0 ~ 15に変換
        _df[col] = _df[col].apply(lambda x: direction_map[x])

        _df[f"{col}_cos"] = np.cos(2 * np.pi * _df[col] / (_df[col].max() + 1))
        _df[f"{col}_sin"] = np.sin(2 * np.pi * _df[col] / (_df[col].max() + 1))
        _df = _df.drop(col, axis=1)

        target_pref = col.split("_")[1]
        other_pref = list(set(pref_list) - set([target_pref]))

        # 内積 window directionベクトル と 他県へのベクトル
        _df[f"{col}_ip_wind_loc_{other_pref[0]}"] = (
            _df[f"{col}_cos"] * LOC_VECTOR_DICT[(other_pref[0], target_pref)][1]
            + _df[f"{col}_sin"] * LOC_VECTOR_DICT[(other_pref[0], target_pref)][0]
        )

        _df[f"{col}_ip_wind_loc_{other_pref[1]}"] = (
            _df[f"{col}_cos"] * LOC_VECTOR_DICT[(other_pref[1], target_pref)][1]
            + _df[f"{col}_sin"] * LOC_VECTOR_DICT[(other_pref[1], target_pref)][0]
        )

        # なす角のcos/arc cos  window directionベクトル と 他県へのベクトル
        _df[f"{col}_cos_wind_loc_{other_pref[0]}"] = _df[
            f"{col}_ip_wind_loc_{other_pref[0]}"
        ] / (
            (
                np.sqrt(_df[f"{col}_cos"] * _df[f"{col}_cos"])
                + np.sqrt(_df[f"{col}_sin"] * _df[f"{col}_sin"])
            )
            * (
                np.sqrt(
                    LOC_VECTOR_DICT[(other_pref[0], target_pref)][1]
                    * LOC_VECTOR_DICT[(other_pref[0], target_pref)][1]
                )
                + np.sqrt(
                    LOC_VECTOR_DICT[(other_pref[0], target_pref)][0]
                    * LOC_VECTOR_DICT[(other_pref[0], target_pref)][0]
                )
            )
        )

        _df[f"{col}_arc_cos_wind_loc_{other_pref[0]}"] = (
            _df[f"{col}_ip_wind_loc_{other_pref[0]}"]
            / (
                (
                    np.sqrt(_df[f"{col}_cos"] * _df[f"{col}_cos"])
                    + np.sqrt(_df[f"{col}_sin"] * _df[f"{col}_sin"])
                )
                * (
                    np.sqrt(
                        LOC_VECTOR_DICT[(other_pref[0], target_pref)][1]
                        * LOC_VECTOR_DICT[(other_pref[0], target_pref)][1]
                    )
                    + np.sqrt(
                        LOC_VECTOR_DICT[(other_pref[0], target_pref)][0]
                        * LOC_VECTOR_DICT[(other_pref[0], target_pref)][0]
                    )
                )
            )
        ).apply(lambda x: np.degrees(np.arccos(x)))

        _df[f"{col}_cos_wind_loc_{other_pref[1]}"] = _df[
            f"{col}_ip_wind_loc_{other_pref[1]}"
        ] / (
            (
                np.sqrt(_df[f"{col}_cos"] * _df[f"{col}_cos"])
                + np.sqrt(_df[f"{col}_sin"] * _df[f"{col}_sin"])
            )
            * (
                np.sqrt(
                    LOC_VECTOR_DICT[(other_pref[1], target_pref)][1]
                    * LOC_VECTOR_DICT[(other_pref[1], target_pref)][1]
                )
                + np.sqrt(
                    LOC_VECTOR_DICT[(other_pref[1], target_pref)][0]
                    * LOC_VECTOR_DICT[(other_pref[1], target_pref)][0]
                )
            )
        )

        _df[f"{col}_arc_cos_wind_loc_{other_pref[1]}"] = _df[
            f"{col}_ip_wind_loc_{other_pref[1]}"
        ] / (
            (
                np.sqrt(_df[f"{col}_cos"] * _df[f"{col}_cos"])
                + np.sqrt(_df[f"{col}_sin"] * _df[f"{col}_sin"])
            )
            * (
                np.sqrt(
                    LOC_VECTOR_DICT[(other_pref[1], target_pref)][1]
                    * LOC_VECTOR_DICT[(other_pref[1], target_pref)][1]
                )
                + np.sqrt(
                    LOC_VECTOR_DICT[(other_pref[1], target_pref)][0]
                    * LOC_VECTOR_DICT[(other_pref[1], target_pref)][0]
                )
            )
        ).apply(
            lambda x: np.degrees(np.arccos(x))
        )

        df_origin = df_origin.reset_index()
        df_origin = df_origin.merge(_df, on="index", how="left")
        df_origin = df_origin.drop("index", axis=1)
        df_origin[f"{col}_no_window"] = (df_origin[col] == 0).astype(int)

        # cos/sin x 風速
        pref = col.split("_")[-1]
        df_origin[f"{col}_cos_mult_window_speed"] = (
            df_origin[f"windspeed_{pref}"] * df_origin[f"{col}_cos"]
        )  # .fillna(0)
        df_origin[f"{col}_sin_mult_window_speed"] = (
            df_origin[f"windspeed_{pref}"] * df_origin[f"{col}_sin"]
        )  # .fillna(0)

        df_origin[f"{col}_cos_mult_window_speed_mult_precipitation"] = df_origin[
            f"{col}_cos_mult_window_speed"
        ] * (1 / (1 + df_origin[f"precipitation_{pref}"]))

        df_origin[f"{col}_sin_mult_window_speed_mult_precipitation"] = df_origin[
            f"{col}_sin_mult_window_speed"
        ] * (1 / (1 + df_origin[f"precipitation_{pref}"]))

        df_origin[
            f"{col}_cos_mult_window_speed_mult_precipitation_mult_day_hour_cos"
        ] = (
            df_origin[f"{col}_cos_mult_window_speed"]
            * (1 / (1 + df_origin[f"precipitation_{pref}"]))
            * df_origin["day_sin_mult_hour_mult_month"]
            #             * df_origin["day_sin_mulit_hour_sin_mult_month"]
        )

        df_origin[
            f"{col}_sin_mult_window_speed_mult_precipitation_mult_day_hour_sin"
        ] = (
            df_origin[f"{col}_sin_mult_window_speed"]
            * (1 / (1 + df_origin[f"precipitation_{pref}"]))
            * df_origin["day_sin_mult_hour_mult_month"]
            #             * df_origin["day_sin_mulit_hour_sin_mult_month"]
        )

        df_origin[f"{col}_cos_mult_window_speed_loc_{other_pref[0]}"] = (
            df_origin[f"windspeed_{pref}"]
            * df_origin[f"{col}_cos"].fillna(0)
            * _df[f"{col}_cos_wind_loc_{other_pref[0]}"]
        )
        df_origin[f"{col}_sin_mult_window_speed"] = (
            df_origin[f"windspeed_{pref}"]
            * df_origin[f"{col}_sin"].fillna(0)
            * _df[f"{col}_cos_wind_loc_{other_pref[0]}"]
        )

        df_origin[f"{col}_cos_mult_window_speed_loc_{other_pref[1]}"] = (
            df_origin[f"windspeed_{pref}"]
            * df_origin[f"{col}_cos"].fillna(0)
            * _df[f"{col}_cos_wind_loc_{other_pref[1]}"]
        )
        df_origin[f"{col}_sin_mult_window_speed"] = (
            df_origin[f"windspeed_{pref}"]
            * df_origin[f"{col}_sin"].fillna(0)
            * _df[f"{col}_cos_wind_loc_{other_pref[1]}"]
        )

    # 全体の和　全体の風向きを期待。
    df_origin[f"window_vector_cos_mult_precipitation"] = (
        df_origin[f"winddirection_utsunomiya_cos_mult_window_speed_mult_precipitation"]
        + df_origin[f"winddirection_tokyo_cos_mult_window_speed_mult_precipitation"]
        + df_origin[f"winddirection_chiba_cos_mult_window_speed_mult_precipitation"]
    )
    df_origin[f"window_vector_sin_mult_precipitation"] = (
        df_origin[f"winddirection_utsunomiya_sin_mult_window_speed_mult_precipitation"]
        + df_origin[f"winddirection_tokyo_sin_mult_window_speed_mult_precipitation"]
        + df_origin[f"winddirection_chiba_sin_mult_window_speed_mult_precipitation"]
    )

    return df_origin


def remove_noise(
    df: pd.DataFrame, window_length: int, polyorder: int = 2, overwite: bool = False
) -> pd.DataFrame:
    _df = df.copy()
    cols = [
        "precipitation_utsunomiya",
        "precipitation_chiba",
        "precipitation_tokyo",
        "temperature_utsunomiya",
        "temperature_chiba",
        "temperature_tokyo",
        "windspeed_utsunomiya",
        "windspeed_chiba",
        "windspeed_tokyo",
    ]
    for col in cols:
        # _df[f"{col}_smooth_{window_length}"] = savgol_filter(_df[col])
        if overwite:
            _df[col] = savgol_filter(
                _df[col], window_length=window_length, polyorder=polyorder
            )
        else:
            _df[f"{col}_smooth_{window_length}"] = savgol_filter(
                _df[col], window_length=window_length, polyorder=polyorder
            )
            _df.loc[
                _df[f"{col}_smooth_{window_length}"] < 0,
                f"{col}_smooth_{window_length}",
            ] = 0

    return _df


def add_precipitation_zero_count_feat(df: pd.DataFrame) -> pd.DataFrame:
    # https://comp.probspace.com/competitions/pollen_counts/discussions/saru_da_mon-Post5943fd8142f960c070d7

    th = 0.5
    for pref in ["utsunomiya", "chiba", "tokyo"]:
        count_list_all = []
        for year in [2017, 2018, 2019, 2020]:
            _df = df[df.year == year].reset_index(drop=True)
            count_list_by_year = []
            n_count = 0
            for e in _df[f"precipitation_{pref}"]:
                if e < th:
                    n_count += 1
                else:
                    n_count = 0
                count_list_by_year.append(np.log1p(n_count))
            count_list_all.extend(count_list_by_year)
        df[f"precipitation_{pref}_count_{th}_2"] = count_list_all

    return df


def temperature_flag(df: pd.DataFrame) -> pd.DataFrame:
    # https://www.allegra.jp/hayfever/how_predict.html
    # 気温が30℃を超え日照時間が多いと花芽が多く作られ、翌年春の花粉飛散量は多くなります。
    # 逆に最高気温が25℃程度にしかならないいわゆる「冷夏」では、木は花芽ではなく枝を伸ばすことに注力するため、
    # 翌年春の花粉飛散量は少なくなります。

    # 30度超えたかのフラグ
    cols = ["temperature_utsunomiya", "temperature_chiba", "temperature_tokyo"]

    for col in cols:
        for th in [20, 25, 30]:
            df[f"{col}_over_{th}"] = (df[col] > th).astype(int)

    return df


def add_sekisan_ondo(
    df: pd.DataFrame,
    cols: List[str] = [
        "temperature_utsunomiya",
        "temperature_tokyo",
        "temperature_chiba",
    ],
) -> pd.DataFrame:
    # https://hp.otenki.com/401/
    # 1/1からの毎日の温度の平均を和を算出していく

    dfs = []
    for year in [2017, 2018, 2019, 2020]:
        _df = df[df.year == year].copy()
        _df["ymd"] = _df["datetime_dt"].apply(lambda x: x.strftime("%Y%m%d"))

        for col in cols:
            _df_temp_mean = _df[["ymd", col]].groupby("ymd").max().reset_index()
            _df_temp_mean = _df_temp_mean.rename(columns={col: f"{col}_daily_mean"})
            _df_temp_mean[f"sekisan_ondo_{col}"] = _df_temp_mean[
                f"{col}_daily_mean"
            ].cumsum()
            _df = _df.merge(_df_temp_mean, on="ymd", how="inner")

        _df = _df.drop("ymd", axis=1)
        dfs.append(_df)

    _df = pd.concat(dfs)

    return _df


def add_sekisan_ondo2(
    df: pd.DataFrame,
    cols: List[str] = [
        "temperature_utsunomiya",
        "temperature_tokyo",
        "temperature_chiba",
    ],
) -> pd.DataFrame:
    # https://hp.otenki.com/401/
    # 1/1からの毎日の温度の平均を和を算出していく

    dfs = []
    for year in [2017, 2018, 2019, 2020]:
        _df = df[df.year == year].reset_index(drop=True).copy()
        # _df["ymd"] = _df["datetime_dt"].apply(lambda x: x.strftime("%Y%m%d"))

        for col in cols:
            _df.loc[_df[col] < 0, col] = 0
            s = _df[col].sum()
            _df[f"sekisan_ondo_{col}_2"] = _df[col].cumsum()
            #_df[f"sekisan_ondo_{col}_2_ratio"] = _df[f"sekisan_ondo_{col}_2"] / s
        dfs.append(_df)

    _df = pd.concat(dfs)

    return _df

def temperature_decompose(df: pd.DataFrame) -> pd.DataFrame:
    from statsmodels.tsa.seasonal import STL

    _df = df.copy()
    for col in ["temperature_tokyo", "temperature_utsunomiya", "temperature_chiba"]:
        res = STL(_df[col], period=24).fit()
        _df[f"{col}_decompose_trend"] = res.trend
        _df[f"{col}_decompose_seasonal"] = res.seasonal
        _df[f"{col}_decompose_resid"] = res.resid
        _df[f"{col}_decompose_minus_trend"] = _df[col] - _df[f"{col}_decompose_trend"]

    return _df


def add_precipitation_mult_month(df: pd.DataFrame) -> pd.DataFrame: 
    _df = df.copy()
    for col in ["precipitation_tokyo", "precipitation_chiba", "precipitation_tokyo"]: 
        _df[f"{col}_mult_month"] = _df[col] * (1 / _df["month"])        

    return _df

def make_feature(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()
    df = time_feat(df)

    # 降水量カウント
    df = add_precipitation_zero_count_feat(df)

    df = remove_noise(df, window_length=7, overwite=False)
    df = remove_noise(df, window_length=13, overwite=False)
    df = remove_noise(df, window_length=25, overwite=False)
    # df = remove_noise(df, window_length=(24 * 7 + 1), overwite=False)

    # ラグ特徴の追加
    feat = [
        "precipitation_utsunomiya",
        "precipitation_chiba",
        "precipitation_tokyo",
        "temperature_utsunomiya",
        "temperature_chiba",
        "temperature_tokyo",
        "windspeed_utsunomiya",
        "windspeed_chiba",
        "windspeed_tokyo",
    ]
    df = add_lag_feat(df, feat, "year")
    
    # ノイズ除去でラグ
    feat_smooth = [col for col in df.columns if "_smooth" in col]
    df = add_lag_feat(df, feat_smooth, "year")

    # 風 one-hot
    df = add_wind_direction_one_hot(df)

    # 風
    df = add_wind_direction_to_cos_sin(df)
    feat_window = [
        f
        for f in df.columns
        if ("cos_mult_window_speed" in f)
        or ("sin_mult_window_speed" in f)
        or ("mult_precipitation" in f)
    ]
    df = add_lag_feat(df, feat_window, "year")

    # 積算温度
    df = add_sekisan_ondo(df)
    #df = add_sekisan_ondo2(df) #mlp dowen

    # 1年ラグ
    df = add_lag_feat_one_year(df, feat)

    # over
    df = temperature_flag(df)
    temp_over_feat = [f for f in df.columns if "_over_" in f]
    df = add_lag_feat_one_year(df, temp_over_feat)

    # decompose
    df = temperature_decompose(df.reset_index(drop=True))
    decompose_feat = [f for f in df.columns if "_decompose_" in f]
    df = add_lag_feat(df, decompose_feat, "year")

    #df = add_precipitation_mult_month(df)

    # df = add_lag_feat_one_year(df, feat_smooth_7)
    # df = add_lag_feat_one_year(df, feat_smooth_13)
    # df = add_lag_feat_one_year(df, feat_smooth_25)
    # df = add_lag_feat_one_year(df, feat_window)    

    return df

# %%
df_train.shape, df_test.shape
# Out:
# ((12240, 16), (336, 16))

# %%
df_test["pollen_utsunomiya"] = -1
df_test["pollen_chiba"] = -1
df_test["pollen_tokyo"] = -1

_df_tmp = pd.concat([df_train, df_test]).reset_index(drop=True)

_df_feat = make_feature(_df_tmp)

_df = _df_feat[_df_feat["pollen_utsunomiya"] != -1].reset_index(drop=True)
_df_test = _df_feat[_df_feat["pollen_utsunomiya"] == -1].reset_index(drop=True)

#_df = _df.reset_index(drop=True)
#_df_test = _df_test.reset_index(drop=True)

_df_test = _df_test.drop(["pollen_utsunomiya", "pollen_chiba", "pollen_tokyo"], axis=1)

# %%
_df.shape, _df_test.shape
# Out:
# ((12240, 1878), (336, 1875))

# %% [markdown]
# # qの確認

# %%
from tqdm import tqdm


def search_best_q_value(
    _df: pd.DataFrame,  # 学習データ
    target_label: str,  # target label
    label_cols: List[str] = [
        "pollen_utsunomiya",
        "pollen_chiba",
        "pollen_tokyo",
    ],
    unused_label: List[str] = [
        "datetime",
        "datetime_dt",
    ],
    q_range=np.arange(4, 40, 4).round(),
    plot: bool = False,
) -> Dict[str, float]:
    """
    https://comp.probspace.com/competitions/pollen_counts/discussions/kotrying-Post833da695e2f337e5a86f
    のq探索を参考に実装
    """
    score_list = []

    for q in tqdm(q_range):

        cols = [col for col in _df.columns if col not in label_cols + unused_label]
        scores = []

        for i, year in enumerate([2017, 2018, 2019]):
            # train year 2 ~ 3月
            # valid year 4/1 ~ 4/15まで
            # test 2020 (2 ~ 3月)
            df_train = _df[
                _df["datetime_dt"] < datetime.datetime(year, 4, 1)
            ].reset_index(drop=True)
            df_val = _df[
                (datetime.datetime(year, 4, 1) <= _df["datetime_dt"])
                & (_df["datetime_dt"] < datetime.datetime(year, 4, 15))
            ].reset_index(drop=True)
            df_test = _df[_df["year"] == 2020].reset_index(drop=True)

            df_train = df_train[df_train[target_label] <= q].reset_index(drop=True)
            df_val = df_val[df_val[target_label] <= q].reset_index(drop=True)

            df_train = df_train[df_train[target_label] >= 0].reset_index(drop=True)
            df_val = df_val[df_val[target_label] >= 0].reset_index(drop=True)

            model = LGBMRegressor(random_state=Config.seed, n_estimators=1000)
            label = target_label            

            model.fit(
                df_train[cols],
                # df_train[label],
                np.log1p(df_train[label]),
                eval_set=(df_val[cols], np.log1p(df_val[label])),
                # early_stopping_rounds=1000,
                eval_metric="fair",
                # verbose=-1,
                callbacks=[
                    lgb.early_stopping(
                        stopping_rounds=1000, verbose=False
                    ),  # early_stopping用コールバック関数
                    lgb.log_evaluation(0),
                ],  # コマンドライン出力用コールバック関数
            )

            test_pred = model.predict(
                df_test[cols], num_iteration=model.best_iteration_
            )
            test_pred = np.expm1(test_pred)
            test_pred = np.where(test_pred < 0, 0, test_pred)  # post-processing

            test_score = mean_absolute_error(df_test[label], test_pred)
            scores.append(test_score)

        mean_score = np.mean(scores)
        score_list.append(mean_score)

    # df_qth = pd.DataFrame({"mae_score": score_list, "q": q_range})
    print(score_list)
    df_qth = pd.DataFrame({"mae_score": score_list, "q": q_range})

    display(df_qth.set_index("q").style.highlight_min())

    if plot:
        ax = sns.lineplot(data=df_qth, x="q", y="mae_score")
        plt.show()

    return df_qth

# %%
#df_qth = search_best_q_value(_df, target_label="pollen_utsunomiya", plot=True)

# %%
#df_qth_tk = search_best_q_value(_df, target_label="pollen_tokyo", plot=True)

# %%
#df_qth_cb = search_best_q_value(_df, target_label="pollen_chiba", plot=True)

# %%
q_ut, q_tk, q_cb = 20, 20, 20
# q_ut, q_tk, q_cb = 36, 24, 36
# q_ut, q_tk, q_cb = 16, 16, 16
# q_ut, q_tk, q_cb = 60, 24, 36

#try
#q_ut, q_tk, q_cb = 20, 20, 20

# %%
def train_lightgbm_with_cv_log(
    _df: pd.DataFrame,  # 学習データ
    df_test: pd.DataFrame,  # テストデータ
    target_label: str,  # target label
    label_cols: List[str] = [
        "pollen_utsunomiya",
        "pollen_chiba",
        "pollen_tokyo",
    ],
    unused_label: List[str] = [
        "datetime",
        "datetime_dt",
        "year",        
    ],    
    plot: bool = False,
    qth: int = 20,
) -> Union[np.array, List[np.float], pd.DataFrame]:

    print(f"========={target_label}==========")
    print(f"qth = {qth}")

    _df = _df.copy()
    df_test = df_test.copy()

    cols = [col for col in _df.columns if col not in label_cols + unused_label]

    folds = TimeSeriesSplit(n_splits=Config.n_splits)
    scores = []
    prediction = np.zeros(len(df_test))
    imps_list = []

    for fold, (train_idx, val_idx) in enumerate(folds.split(_df)):
        print(f"=====fold {fold}=======")

        df_train = _df.iloc[train_idx].reset_index(drop=True)
        df_val = _df.iloc[val_idx].reset_index(drop=True)
        
        print("train shape", df_train.shape, "test shape", df_val.shape)

        model = LGBMRegressor(random_state=Config.seed, n_estimators=1000)

        label = target_label
        
        # # データがv2になってから花粉飛散量がマイナスのがある。削除する。
        df_train = df_train[df_train[label] >= 0].reset_index(drop=True)
        df_val = df_val[df_val[label] >= 0].reset_index(drop=True)

        df_train = df_train[df_train[label] <= qth].reset_index(drop=True)
        df_val = df_val[df_val[label] <= qth].reset_index(drop=True)
        

        model.fit(
            df_train[cols],            
            np.log1p(df_train[label]),
            eval_set=(df_val[cols], np.log1p(df_val[label])),            
            eval_metric="fair",            
            callbacks=[
                lgb.early_stopping(
                    stopping_rounds=1000, verbose=False
                ),  # early_stopping用コールバック関数
                lgb.log_evaluation(0),
            ],  # コマンドライン出力用コールバック関数
        )

        # validation
        val_pred = model.predict(df_val[cols], num_iteration=model.best_iteration_)
        val_pred = np.expm1(val_pred)
        val_score = mean_absolute_error(df_val[label], val_pred)
        scores.append(val_score)
        print("score =", val_score)

        if plot:
            _df_val = df_val.copy()
            _df_val["pred"] = val_pred
            plt.figure(figsize=(20, 10))
            ax = sns.lineplot(data=_df_val, x="datetime_dt", y=label)
            ax = sns.lineplot(data=_df_val, x="datetime_dt", y="pred")
            plt.show()

        _pred = model.predict(df_test[cols], num_iteration=model.best_iteration_)
        _pred = np.expm1(_pred)
        prediction += _pred / Config.n_splits
        prediction = np.where(prediction < 0, 0, prediction)

        imps = model.feature_importances_
        imps_list.append(imps)

    imps = np.mean(imps_list, axis=0)
    df_imps = pd.DataFrame({"columns": _df[cols].columns.tolist(), "feat_imp": imps})
    df_imps = df_imps.sort_values("feat_imp", ascending=False).reset_index(drop=True)

    return prediction, scores, df_imps

# %% [markdown]
# # Utsunomiya pred

# %%
unused_cols = [col for col in _df.columns if ("temperature_utsunomiya" in col) and ("decompose" not in col)]

# %%
utsunomiya_prediction, scores, df_imps = train_lightgbm_with_cv_log(
    _df,
    _df_test,
    target_label="pollen_utsunomiya",
    plot=True,
    qth=q_ut,
    unused_label=["year", "datetime", "datetime_dt"] + unused_cols,
)

for i, score in enumerate(scores):
    print(f" fold_{i} mae: {score}")
print(f"mean {np.mean(scores)}")

utsunomiya_score = np.mean(scores)
# Out:
# =========pollen_utsunomiya==========
# qth = 20
# =====fold 0=======
# train shape (4080, 1878) test shape (4080, 1878)
# score = 3.2122717533587903
# =====fold 1=======
# train shape (8160, 1878) test shape (4080, 1878)
# score = 3.28214076714094
#  fold_0 mae: 3.2122717533587903
#  fold_1 mae: 3.28214076714094
# mean 3.2472062602498655

# %%
__df_test = _df_test.copy()
__df_test["pollen_utsunomiya"] = utsunomiya_prediction
plt.figure(figsize=(20, 10))
ax = sns.lineplot(data=_df[_df.year==2020], x="datetime_dt", y="pollen_utsunomiya")
ax = sns.lineplot(data=__df_test, x="datetime_dt", y="pollen_utsunomiya")

# %%
_, ax = plt.subplots(figsize=(10, 8))
sns.barplot(data=df_imps.head(30), x="feat_imp", y="columns")
# Out:
# <AxesSubplot:xlabel='feat_imp', ylabel='columns'>

# %% [markdown]
# # Tokyo pred

# %%
unused_cols = [col for col in _df.columns if ("temperature_tokyo" in col) and ("decompose" not in col)]

# %%
tokyo_prediction, scores, df_imps = train_lightgbm_with_cv_log(
    _df,
    _df_test,
    target_label="pollen_tokyo",
    plot=True,
    qth=q_tk,
    unused_label=["year", "datetime", "datetime_dt"] + unused_cols,
)


for i, score in enumerate(scores):
    print(f" fold_{i} mae: {score}")
print(f"mean: {np.mean(scores)}")

tokyo_score = np.mean(scores)
# Out:
# =========pollen_tokyo==========
# qth = 20
# =====fold 0=======
# train shape (4080, 1878) test shape (4080, 1878)
# score = 3.343466468909563
# =====fold 1=======
# train shape (8160, 1878) test shape (4080, 1878)
# score = 3.61426156570616
#  fold_0 mae: 3.343466468909563
#  fold_1 mae: 3.61426156570616
# mean: 3.4788640173078615

# %%
__df_test = _df_test.copy()
__df_test["pollen_tokyo"] = tokyo_prediction
plt.figure(figsize=(20, 10))
ax = sns.lineplot(data=_df[_df.year==2020], x="datetime_dt", y="pollen_tokyo")
ax = sns.lineplot(data=__df_test, x="datetime_dt", y="pollen_tokyo")

# %%
_, ax = plt.subplots(figsize=(10, 8))
sns.barplot(data=df_imps.head(30), x="feat_imp", y="columns")
# Out:
# <AxesSubplot:xlabel='feat_imp', ylabel='columns'>

# %% [markdown]
# # Chiba prediciton

# %%
#unused_cols = [col for col in _df.columns if ("temperature_chiba" in col) and ("decompose" not in col)]

# %%
chiba_prediction, scores, df_imps = train_lightgbm_with_cv_log(
    _df,
    _df_test,
    target_label="pollen_chiba",
    plot=True,
    qth=q_cb,
    unused_label=["year", "datetime", "datetime_dt"] #+ unused_cols,
)

for i, score in enumerate(scores):
    print(f" fold_{i} mae: {score}")
print(f"mean: {np.mean(scores)}")


chiba_score = np.mean(scores)
# Out:
# =========pollen_chiba==========
# qth = 20
# =====fold 0=======
# train shape (4080, 1878) test shape (4080, 1878)
# score = 3.623070196184175
# =====fold 1=======
# train shape (8160, 1878) test shape (4080, 1878)
# score = 3.809592450333409
#  fold_0 mae: 3.623070196184175
#  fold_1 mae: 3.809592450333409
# mean: 3.716331323258792

# %%
__df_test = _df_test.copy()
__df_test["pollen_chiba"] = chiba_prediction
plt.figure(figsize=(20, 10))
ax = sns.lineplot(data=_df[_df.year==2020], x="datetime_dt", y="pollen_chiba")
ax = sns.lineplot(data=__df_test, x="datetime_dt", y="pollen_chiba")

# %%
_, ax = plt.subplots(figsize=(10, 8))
sns.barplot(data=df_imps.head(30), x="feat_imp", y="columns")
# Out:
# <AxesSubplot:xlabel='feat_imp', ylabel='columns'>

# %% [markdown]
# # submission

# %%
df_sub = _df_test[["datetime"]]

# %%
df_sub.loc[:, "pollen_utsunomiya"] = utsunomiya_prediction
df_sub.loc[:, "pollen_chiba"] = chiba_prediction
df_sub.loc[:, "pollen_tokyo"] = tokyo_prediction
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1667: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value

# %% [markdown]
# # 補正処理
#
# ## utsunomiya
# - 202004week_0    434.422905
# - 202004week_1     -0.568712
#
# ## tokyo
# - 202004week_0    115.754492
# - 202004week_1     -0.732169
#
# ## chiba
# - 202004week_0    20.465855
# - 202004week_1    -0.373396

# %%
# todo

# %%
df_sub.head()
df_sub.to_csv(f"sub.csv", index=None)

# %%
utsunomiya_score, tokyo_score, chiba_score, np.mean(
    [utsunomiya_score, tokyo_score, chiba_score]
)
# Out:
# (3.2472062602498655, 3.4788640173078615, 3.716331323258792, 3.4808005336055063)

# %% [markdown]
# - (3.2992873512805874, 3.4586717988839144, 3.689065188308221, 3.4823414461575743) LB: 12.78 q = 20, 20, 20
# - (3.2615237031261897, 1.803599091668639, 3.700513642291193, 2.921878812362007)

# %%
if not Config.mlp:
    raise ValueError("stop")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_5876/3820233071.py in <module>
#       1 if not Config.mlp:
# ----> 2     raise ValueError("stop")
#
# ValueError: stop

# %%
_df.head()
# Out:
#      datetime  precipitation_utsunomiya  precipitation_chiba  \
# 0  2017020101                       0.0                  0.0
# 1  2017020102                       0.0                  0.0
# 2  2017020103                       0.0                  0.0
# 3  2017020104                       0.0                  0.0
# 4  2017020105                       0.0                  0.0
#
#    precipitation_tokyo  temperature_utsunomiya  temperature_chiba  \
# 0                  0.0                    -1.0                4.1
# 1                  0.0                    -1.1                4.2
# 2                  0.0                    -0.7                4.2
# 3                  0.0                    -1.1                4.4
# 4                  0.0                    -1.2                4.1
#
#    temperature_tokyo  winddirection_utsunomiya  winddirection_chiba  \
# 0                2.9                        16                    1
# 1                2.6                         1                    1
# 2                2.4                         1                   15
# 3                1.8                         1                   15
# 4                1.5                         2                   14
#
#    winddirection_tokyo  ...  \
# 0                    2  ...
# 1                    1  ...
# 2                   16  ...
# 3                    1  ...
# 4                   14  ...
#
#    rolling216_mean_temperature_tokyo_decompose_resid  \
# 0                                           0.307548
# 1                                           0.306531
# 2                                           0.272960
# 3                                           0.295905
# 4                                           0.206762
#
#    rolling216_mean_temperature_tokyo_decompose_minus_trend  \
# 0                                          -1.881072
# 1                                          -2.033130
# 2                                          -2.151887
# 3                                          -2.362335
# 4                                          -2.549466
#
#    rolling216_mean_temperature_utsunomiya_decompose_trend  \
# 0                                           3.026912
# 1                                           3.028457
# 2                                           3.029974
# 3                                           3.031460
# 4                                           3.032916
#
#    rolling216_mean_temperature_utsunomiya_decompose_seasonal  \
# 0                                          -2.976872
# 1                                          -3.281375
# 2                                          -3.138505
# 3                                          -3.264320
# 4                                          -3.408516
#
#    rolling216_mean_temperature_utsunomiya_decompose_resid  \
# 0                                          -1.050039
# 1                                          -0.797081
# 2                                          -0.824802
# 3                                          -0.742140
# 4                                          -0.644400
#
#    rolling216_mean_temperature_utsunomiya_decompose_minus_trend  \
# 0                                          -4.026912
# 1                                          -4.078457
# 2                                          -3.963307
# 3                                          -4.006460
# 4                                          -4.052916
#
#   rolling216_mean_temperature_chiba_decompose_trend  \
# 0                                          6.658000
# 1                                          6.656192
# 2                                          6.654308
# 3                                          6.652341
# 4                                          6.650283
#
#    rolling216_mean_temperature_chiba_decompose_seasonal  \
# 0                                          -2.833122
# 1                                          -2.877097
# 2                                          -2.803718
# 3                                          -2.720946
# 4                                          -2.751653
#
#    rolling216_mean_temperature_chiba_decompose_resid  \
# 0                                           0.275122
# 1                                           0.370905
# 2                                           0.316076
# 3                                           0.293605
# 4                                           0.301370
#
#    rolling216_mean_temperature_chiba_decompose_minus_trend
# 0                                          -2.558000
# 1                                          -2.506192
# 2                                          -2.487642
# 3                                          -2.427341
# 4                                          -2.450283
#
# [5 rows x 1878 columns]

# %% [markdown]
# # keras MLP

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
#from keras.optimizers import SGD
from tensorflow.keras.optimizers import SGD
from keras.callbacks import EarlyStopping

# %%
def generate_model(input_dim):
    model = Sequential()

    model.add(Dense(1024, input_dim=input_dim))
    model.add(Activation('relu'))
    model.add(Dropout(0.25))
    model.add(Dense(500, input_dim=1024))
    model.add(Activation('relu'))
    model.add(Dropout(0.25))
    model.add(Dense(100, input_dim=500))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(50, input_dim=100))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(1, input_dim=1))
    model.compile(optimizer='Adam', loss='mean_absolute_error', metrics=['mae'])    
    return model

# %%
from sklearn.preprocessing import Normalizer, StandardScaler


def train_keras(
    __df: pd.DataFrame,  # 学習データ
    __df_test: pd.DataFrame,  # テストデータ
    target_label: str,  # target label
    label_cols: List[str] = ["pollen_utsunomiya", "pollen_chiba", "pollen_tokyo",],
    unused_label: List[str] = ["datetime", "datetime_dt",],
    plot: bool = False,
    qth: int = 20,
) -> Union[np.array, List[np.float]]:

    _df = __df.copy()
    df_test = __df_test.copy()
    _df = _df.fillna(-1)
    df_test = df_test.fillna(-1)
        
    print(f"========={target_label}==========")
    print(f"qth = {qth}")
    
    cols = [col for col in _df.columns if col not in label_cols + unused_label]

    folds = TimeSeriesSplit(n_splits=Config.n_splits)
    scores = []
    prediction = np.zeros(len(df_test))    

    for fold, (train_idx, val_idx) in enumerate(folds.split(_df)):
        print(f"=====fold {fold}=======")
                
        df_train = _df.iloc[train_idx].reset_index(drop=True)
        df_val = _df.iloc[val_idx].reset_index(drop=True)

        print("train shape", df_train.shape, "test shape", df_val.shape)

        label = target_label
        
        # # データがv2になってから花粉飛散量がマイナスのがある。削除する。
        df_train = df_train[df_train[label] >= 0].reset_index(drop=True)
        df_val = df_val[df_val[label] >= 0].reset_index(drop=True)
        
        df_train = df_train[df_train[label] <= qth].reset_index(drop=True)
        df_val = df_val[df_val[label] <= qth].reset_index(drop=True)

        normalizer = Normalizer().fit(df_train[cols])    
        X = normalizer.transform(df_train[cols])
        
        val_X = normalizer.transform(df_val[cols])
        
        model = generate_model(df_train[cols].shape[1])

        early_stopping = EarlyStopping(
                            monitor='val_mae',
                            min_delta=0.0,
                            patience=100,
        )

        model.fit(X , np.log1p(df_train[label]), validation_data=(val_X, np.log1p(df_val[label])),
                  epochs=500, batch_size=128, callbacks=[early_stopping])      

        # validation
        val_pred = model.predict(val_X)
        val_pred = np.expm1(val_pred)
        val_score = mean_absolute_error(df_val[label], val_pred)
        scores.append(val_score)
        
        if plot:
            _df_val = df_val.copy()
            _df_val["pred"] = val_pred
            plt.figure(figsize=(10, 6))
            ax = sns.lineplot(data=_df_val, x="datetime_dt", y=label)
            ax = sns.lineplot(data=_df_val, x="datetime_dt", y="pred")
            plt.show()
            
        test_X = normalizer.transform(df_test[cols])

        _pred = model.predict(test_X)
        _pred = _pred.flatten()
        _pred = np.expm1(_pred)
        prediction += _pred / Config.n_splits
        prediction = np.where(prediction < 0, 0, prediction)

    return prediction, scores

# %% [markdown]
# # Utsunomiya prediction

# %%
unused_cols = [col for col in _df.columns if (("temperature_utsunomiya" in col) and ("decompose" not in col)) or ("one_hot" in col)]

# %%
utsunomiya_prediction, scores = train_keras(
   _df.copy(), _df_test, target_label="pollen_utsunomiya", plot=True, qth=q_ut, unused_label=["year", "datetime", "datetime_dt"] + unused_cols,
)


for i, score in enumerate(scores):
    print(f" fold_{i} mae: {score}")
print(f"mean {np.mean(scores)}")

utsunomiya_score_mlp = np.mean(scores)
# Out:
# =========pollen_utsunomiya==========
# qth = 20
# =====fold 0=======
# train shape (4080, 1878) test shape (4080, 1878)
# 2022-11-23 10:32:54.924997: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX512F
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
#
# User settings:
#
#    KMP_AFFINITY=granularity=fine,verbose,compact,1,0
#    KMP_BLOCKTIME=0
#    KMP_DUPLICATE_LIB_OK=True
#    KMP_INIT_AT_FORK=FALSE
#    KMP_SETTINGS=1
#    KMP_WARNINGS=0
#
# Effective settings:
#
#    KMP_ABORT_DELAY=0
#    KMP_ADAPTIVE_LOCK_PROPS='1,1024'
#    KMP_ALIGN_ALLOC=64
#    KMP_ALL_THREADPRIVATE=128
#    KMP_ATOMIC_MODE=2
#    KMP_BLOCKTIME=0
#    KMP_CPUINFO_FILE: value is not defined
#    KMP_DETERMINISTIC_REDUCTION=false
#    KMP_DEVICE_THREAD_LIMIT=2147483647
#    KMP_DISP_NUM_BUFFERS=7
#    KMP_DUPLICATE_LIB_OK=true
#    KMP_ENABLE_TASK_THROTTLING=true
#    KMP_FORCE_REDUCTION: value is not defined
#    KMP_FOREIGN_THREADS_THREADPRIVATE=true
#    KMP_FORKJOIN_BARRIER='2,2'
#    KMP_FORKJOIN_BARRIER_PATTERN='hyper,hyper'
#    KMP_GTID_MODE=3
#    KMP_HANDLE_SIGNALS=false
#    KMP_HOT_TEAMS_MAX_LEVEL=1
#    KMP_HOT_TEAMS_MODE=0
#    KMP_INIT_AT_FORK=true
#    KMP_LIBRARY=throughput
#    KMP_LOCK_KIND=queuing
#    KMP_MALLOC_POOL_INCR=1M
#    KMP_NUM_LOCKS_IN_BLOCK=1
#    KMP_PLAIN_BARRIER='2,2'
#    KMP_PLAIN_BARRIER_PATTERN='hyper,hyper'
#    KMP_REDUCTION_BARRIER='1,1'
#    KMP_REDUCTION_BARRIER_PATTERN='hyper,hyper'
#    KMP_SCHEDULE='static,balanced;guided,iterative'
#    KMP_SETTINGS=true
#    KMP_SPIN_BACKOFF_PARAMS='4096,100'
#    KMP_STACKOFFSET=64
#    KMP_STACKPAD=0
#    KMP_STACKSIZE=10M
#    KMP_STORAGE_MAP=false
#    KMP_TASKING=2
#    KMP_TASKLOOP_MIN_TASKS=0
#    KMP_TASK_STEALING_CONSTRAINT=1
#    KMP_TEAMS_THREAD_LIMIT=4
#    KMP_TOPOLOGY_METHOD=all
#    KMP_USE_YIELD=1
#    KMP_VERSION=false
#    KMP_WARNINGS=false
#    OMP_AFFINITY_FORMAT='OMP: pid %P tid %i thread %n bound to OS proc set {%A}'
#    OMP_ALLOCATOR=omp_default_mem_alloc
#    OMP_CANCELLATION=false
#    OMP_DEFAULT_DEVICE=0
#    OMP_DISPLAY_AFFINITY=false
#    OMP_DISPLAY_ENV=false
#    OMP_DYNAMIC=false
#    OMP_MAX_ACTIVE_LEVELS=1
#    OMP_MAX_TASK_PRIORITY=0
#    OMP_NESTED: deprecated; max-active-levels-var=1
#    OMP_NUM_THREADS: value is not defined
#    OMP_PLACES: value is not defined
#    OMP_PROC_BIND='intel'
#    OMP_SCHEDULE='static'
#    OMP_STACKSIZE=10M
#    OMP_TARGET_OFFLOAD=DEFAULT
#    OMP_THREAD_LIMIT=2147483647
#    OMP_WAIT_POLICY=PASSIVE
#    KMP_AFFINITY='verbose,warnings,respect,granularity=fine,compact,1,0'
#
# 2022-11-23 10:32:54.926114: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2022-11-23 10:32:55.069028: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/500
# 19/19 [==============================] - 1s 29ms/step - loss: 1.0031 - mae: 1.0031 - val_loss: 0.9083 - val_mae: 0.9083
# Epoch 2/500
# 19/19 [==============================] - 0s 20ms/step - loss: 0.9028 - mae: 0.9028 - val_loss: 0.8788 - val_mae: 0.8788
# Epoch 3/500
# 19/19 [==============================] - 0s 20ms/step - loss: 0.8597 - mae: 0.8597 - val_loss: 0.8284 - val_mae: 0.8284
# Epoch 4/500
# 19/19 [==============================] - 0s 20ms/step - loss: 0.7948 - mae: 0.7948 - val_loss: 0.7922 - val_mae: 0.7922
# Epoch 5/500
# 19/19 [==============================] - 0s 20ms/step - loss: 0.7558 - mae: 0.7558 - val_loss: 0.7571 - val_mae: 0.7571
# Epoch 6/500
# 19/19 [==============================] - 0s 19ms/step - loss: 0.7036 - mae: 0.7036 - val_loss: 0.7433 - val_mae: 0.7433
# Epoch 7/500
# 19/19 [==============================] - 0s 21ms/step - loss: 0.6911 - mae: 0.6911 - val_loss: 0.7748 - val_mae: 0.7748
# Epoch 8/500
# 19/19 [==============================] - 0s 19ms/step - loss: 0.6872 - mae: 0.6872 - val_loss: 0.7683 - val_mae: 0.7683
# Epoch 9/500
# 19/19 [==============================] - 0s 19ms/step - loss: 0.6577 - mae: 0.6577 - val_loss: 0.7155 - val_mae: 0.7155
# Epoch 10/500
# 19/19 [==============================] - 0s 20ms/step - loss: 0.6372 - mae: 0.6372 - val_loss: 0.7430 - val_mae: 0.7430
# Epoch 11/500
# 19/19 [==============================] - 0s 19ms/step - loss: 0.6108 - mae: 0.6108 - val_loss: 0.7214 - val_mae: 0.7214
# Epoch 12/500
# 19/19 [==============================] - 0s 22ms/step - loss: 0.6169 - mae: 0.6169 - val_loss: 0.7520 - val_mae: 0.7520
# Epoch 13/500
# 19/19 [==============================] - 0s 20ms/step - loss: 0
500
# 36/36 [==============================] - 1s 18ms/step - loss: 0.4308 - mae: 0.4308 - val_loss: 0.6246 - val_mae: 0.6246
# Epoch 98/500
# 36/36 [==============================] - 1s 18ms/step - loss: 0.4366 - mae: 0.4366 - val_loss: 0.6290 - val_mae: 0.6290
# Epoch 99/500
# 36/36 [==============================] - 1s 17ms/step - loss: 0.4300 - mae: 0.4300 - val_loss: 0.6585 - val_mae: 0.6585
# Epoch 100/500
# 36/36 [==============================] - 1s 19ms/step - loss: 0.4100 - mae: 0.4100 - val_loss: 0.6188 - val_mae: 0.6188
# Epoch 101/500
# 36/36 [==============================] - 1s 18ms/step - loss: 0.4304 - mae: 0.4304 - val_loss: 0.6300 - val_mae: 0.6300
# Epoch 102/500
# 36/36 [==============================] - 1s 18ms/step - loss: 0.4120 - mae: 0.4120 - val_loss: 0.6718 - val_mae: 0.6718
# Epoch 103/500
# 36/36 [==============================] - 1s 17ms/step - loss: 0.4425 - mae: 0.4425 - val_loss: 0.6319 - val_mae: 0.6319
# Epoch 104/500
# 36/36 [==============================] - 1s 18ms/step - loss: 0.4291 - mae: 0.4291 - val_loss: 0.6267 - val_mae: 0.6267
# Epoch 105/500
# 36/36 [==============================] - 1s 20ms/step - loss: 0.4166 - mae: 0.4166 - val_loss: 0.6175 - val_mae: 0.6175
# Epoch 106/500
# 36/36 [==============================] - 1s 18ms/step - loss: 0.4284 - mae: 0.4284 - val_loss: 0.6388 - val_mae: 0.6388
# Epoch 107/500
# 36/36 [==============================] - 1s 18ms/step - loss: 0.4194 - mae: 0.4194 - val_loss: 0.6461 - val_mae: 0.6461
# Epoch 108/500
# 36/36 [==============================] - 1s 17ms/step - loss: 0.4280 - mae: 0.4280 - val_loss: 0.6164 - val_mae: 0.6164
# Epoch 109/500
# 36/36 [==============================] - 1s 17ms/step - loss: 0.4192 - mae: 0.4192 - val_loss: 0.6107 - val_mae: 0.6107
# Epoch 110/500
# 36/36 [==============================] - 1s 18ms/step - loss: 0.4101 - mae: 0.4101 - val_loss: 0.6075 - val_mae: 0.6075
# Epoch 111/500
# 36/36 [==============================] - 1s 18ms/step - loss: 0.4036 - mae: 0.4036 - val_loss: 0.6272 - val_mae: 0.6272
# Epoch 112/500
# 36/36 [==============================] - 1s 18ms/step - loss: 0.4026 - mae: 0.4026 - val_loss: 0.6274 - val_mae: 0.6274
# Epoch 113/500
# 36/36 [==============================] - 1s 20ms/step - loss: 0.4019 - mae: 0.4019 - val_loss: 0.6613 - val_mae: 0.6613
# Epoch 114/500
# 36/36 [==============================] - 1s 18ms/step - loss: 0.4182 - mae: 0.4182 - val_loss: 0.6107 - val_mae: 0.6107
# Epoch 115/500
# 36/36 [==============================] - 1s 18ms/step - loss: 0.4050 - mae: 0.4050 - val_loss: 0.6330 - val_mae: 0.6330
# Epoch 116/500
# 36/36 [==============================] - 1s 17ms/step - loss: 0.4223 - mae: 0.4223 - val_loss: 0.6447 - val_mae: 0.6447
# Epoch 117/500
# 36/36 [==============================] - 1s 18ms/step - loss: 0.4081 - mae: 0.4081 - val_loss: 0.6395 - val_mae: 0.6395
# Epoch 118/500
# 36/36 [==============================] - 1s 18ms/step - loss: 0.4047 - mae: 0.4047 - val_loss: 0.6367 - val_mae: 0.6367
# Epoch 119/500
# 36/36 [==============================] - 1s 18ms/step - loss: 0.3916 - mae: 0.3916 - val_loss: 0.6702 - val_mae: 0.6702
# Epoch 120/500
# 36/36 [==============================] - 1s 18ms/step - loss: 0.4147 - mae: 0.4147 - val_loss: 0.6475 - val_mae: 0.6475
#  fold_0 mae: 4.048542348939023
#  fold_1 mae: 3.734057504480166
# mean 3.8912999267095945

# %%
__df_test = _df_test.copy()
__df_test["pollen_tokyo"] = tokyo_prediction
plt.figure(figsize=(20, 10))
ax = sns.lineplot(data=_df[_df.year==2020], x="datetime_dt", y="pollen_tokyo")
ax = sns.lineplot(data=__df_test, x="datetime_dt", y="pollen_tokyo")

# %% [markdown]
# # tokyo pred

# %%
unused_cols = [col for col in _df.columns if (("temperature_tokyo" in col) and ("decompose" not in col)) or ("one_hot" in col)]

# %%
tokyo_prediction, scores = train_keras(
    _df.copy(), _df_test, target_label="pollen_tokyo", plot=True, qth=q_tk, unused_label=["year", "datetime", "datetime_dt"] + unused_cols
)

for i, score in enumerate(scores):
    print(f" fold_{i} mae: {score}")
print(f"mean: {np.mean(scores)}")

tokyo_score_mlp = np.mean(scores)
# Out:
# =========pollen_tokyo==========
# qth = 20
# =====fold 0=======
# train shape (4080, 1878) test shape (4080, 1878)
# Epoch 1/500
# 23/23 [==============================] - 1s 26ms/step - loss: 1.1186 - mae: 1.1186 - val_loss: 0.9879 - val_mae: 0.9879
# Epoch 2/500
# 23/23 [==============================] - 1s 23ms/step - loss: 1.0051 - mae: 1.0051 - val_loss: 0.9221 - val_mae: 0.9221
# Epoch 3/500
# 23/23 [==============================] - 0s 20ms/step - loss: 0.9087 - mae: 0.9087 - val_loss: 0.8898 - val_mae: 0.8898
# Epoch 4/500
# 23/23 [==============================] - 0s 20ms/step - loss: 0.8453 - mae: 0.8453 - val_loss: 0.8231 - val_mae: 0.8231
# Epoch 5/500
# 23/23 [==============================] - 0s 20ms/step - loss: 0.7717 - mae: 0.7717 - val_loss: 0.7461 - val_mae: 0.7461
# Epoch 6/500
# 23/23 [==============================] - 0s 20ms/step - loss: 0.7467 - mae: 0.7467 - val_loss: 0.8119 - val_mae: 0.8119
# Epoch 7/500
# 23/23 [==============================] - 0s 21ms/step - loss: 0.7180 - mae: 0.7180 - val_loss: 0.7826 - val_mae: 0.7826
# Epoch 8/500
# 23/23 [==============================] - 0s 20ms/step - loss: 0.7163 - mae: 0.7163 - val_loss: 0.7551 - val_mae: 0.7551
# Epoch 9/500
# 23/23 [==============================] - 0s 19ms/step - loss: 0.6831 - mae: 0.6831 - val_loss: 0.7866 - val_mae: 0.7866
# Epoch 10/500
# 23/23 [==============================] - 0s 19ms/step - loss: 0.6599 - mae: 0.6599 - val_loss: 0.7547 - val_mae: 0.7547
# Epoch 11/500
# 23/23 [==============================] - 0s 20ms/step - loss: 0.6248 - mae: 0.6248 - val_loss: 0.7494 - val_mae: 0.7494
# Epoch 12/500
# 23/23 [==============================] - 0s 21ms/step - loss: 0.6192 - mae: 0.6192 - val_loss: 0.7491 - val_mae: 0.7491
# Epoch 13/500
# 23/23 [==============================] - 0s 19ms/step - loss: 0.6131 - mae: 0.6131 - val_loss: 0.7842 - val_mae: 0.7842
# Epoch 14/500
# 23/23 [==============================] - 0s 20ms/step - loss: 0.6173 - mae: 0.6173 - val_loss: 0.7768 - val_mae: 0.7768
# Epoch 15/500
# 23/23 [==============================] - 0s 20ms/step - loss: 0.6032 - mae: 0.6032 - val_loss: 0.7605 - val_mae: 0.7605
# Epoch 16/500
# 23/23 [==============================] - 0s 19ms/step - loss: 0.5886 - mae: 0.5886 - val_loss: 0.7539 - val_mae: 0.7539
# Epoch 17/500
# 23/23 [==============================] - 0s 21ms/step - loss: 0.6000 - mae: 0.6000 - val_loss: 0.7966 - val_mae: 0.7966
# Epoch 18/500
# 23/23 [==============================] - 0s 19ms/step - loss: 0.5786 - mae: 0.5786 - val_loss: 0.7273 - val_mae: 0.7273
# Epoch 19/500
# 23/23 [==============================] - 0s 19ms/step - loss: 0.5750 - mae: 0.5750 - val_loss: 0.6998 - val_mae: 0.6998
# Epoch 20/500
# 23/23 [==============================] - 0s 20ms/step - loss: 0.5789 - mae: 0.5789 - val_loss: 0.7466 - val_mae: 0.7466
# Epoch 21/500
# 23/23 [==============================] - 1s 23ms/step - loss: 0.5604 - mae: 0.5604 - val_loss: 0.7427 - val_mae: 0.7427
# Epoch 22/500
# 23/23 [==============================] - 0s 21ms/step - loss: 0.5556 - mae: 0.5556 - val_loss: 0.8148 - val_mae: 0.8148
# Epoch 23/500
# 23/23 [==============================] - 0s 19ms/step - loss: 0.5643 - mae: 0.5643 - val_loss: 0.8169 - val_mae: 0.8169
# Epoch 24/500
# 23/23 [==============================] - 0s 20ms/step - loss: 0
500
# 23/23 [==============================] - 0s 21ms/step - loss: 0.3695 - mae: 0.3695 - val_loss: 0.7447 - val_mae: 0.7447
# Epoch 199/500
# 23/23 [==============================] - 0s 21ms/step - loss: 0.3579 - mae: 0.3579 - val_loss: 0.7455 - val_mae: 0.7455
# Epoch 200/500
# 23/23 [==============================] - 0s 20ms/step - loss: 0.3628 - mae: 0.3628 - val_loss: 0.7706 - val_mae: 0.7706
# Epoch 201/500
# 23/23 [==============================] - 0s 21ms/step - loss: 0.4067 - mae: 0.4067 - val_loss: 0.7447 - val_mae: 0.7447
# Epoch 202/500
# 23/23 [==============================] - 1s 23ms/step - loss: 0.3643 - mae: 0.3643 - val_loss: 0.7776 - val_mae: 0.7776
# Epoch 203/500
# 23/23 [==============================] - 0s 21ms/step - loss: 0.3665 - mae: 0.3665 - val_loss: 0.7547 - val_mae: 0.7547
# Epoch 204/500
# 23/23 [==============================] - 0s 21ms/step - loss: 0.3668 - mae: 0.3668 - val_loss: 0.7663 - val_mae: 0.7663
# Epoch 205/500
# 23/23 [==============================] - 0s 21ms/step - loss: 0.3781 - mae: 0.3781 - val_loss: 0.7700 - val_mae: 0.7700
# Epoch 206/500
# 23/23 [==============================] - 0s 22ms/step - loss: 0.3764 - mae: 0.3764 - val_loss: 0.7479 - val_mae: 0.7479
# Epoch 207/500
# 23/23 [==============================] - 0s 21ms/step - loss: 0.3675 - mae: 0.3675 - val_loss: 0.7654 - val_mae: 0.7654
# Epoch 208/500
# 23/23 [==============================] - 0s 21ms/step - loss: 0.3514 - mae: 0.3514 - val_loss: 0.7307 - val_mae: 0.7307
# Epoch 209/500
# 23/23 [==============================] - 0s 21ms/step - loss: 0.3716 - mae: 0.3716 - val_loss: 0.7809 - val_mae: 0.7809
# Epoch 210/500
# 23/23 [==============================] - 0s 21ms/step - loss: 0.3674 - mae: 0.3674 - val_loss: 0.7131 - val_mae: 0.7131
# Epoch 211/500
# 23/23 [==============================] - 0s 21ms/step - loss: 0.3634 - mae: 0.3634 - val_loss: 0.7156 - val_mae: 0.7156
# Epoch 212/500
# 23/23 [==============================] - 0s 21ms/step - loss: 0.3602 - mae: 0.3602 - val_loss: 0.7678 - val_mae: 0.7678
# Epoch 213/500
# 23/23 [==============================] - 0s 21ms/step - loss: 0.3767 - mae: 0.3767 - val_loss: 0.7204 - val_mae: 0.7204
# Epoch 214/500
# 23/23 [==============================] - 0s 21ms/step - loss: 0.3768 - mae: 0.3768 - val_loss: 0.7203 - val_mae: 0.7203
# Epoch 215/500
# 23/23 [==============================] - 1s 23ms/step - loss: 0.3512 - mae: 0.3512 - val_loss: 0.7309 - val_mae: 0.7309
# Epoch 216/500
# 23/23 [==============================] - 0s 21ms/step - loss: 0.3581 - mae: 0.3581 - val_loss: 0.7494 - val_mae: 0.7494
# Epoch 217/500
# 23/23 [==============================] - 0s 21ms/step - loss: 0.3561 - mae: 0.3561 - val_loss: 0.7256 - val_mae: 0.7256
# Epoch 218/500
# 23/23 [==============================] - 0s 21ms/step - loss: 0.3657 - mae: 0.3657 - val_loss: 0.7451 - val_mae: 0.7451
# Epoch 219/500
# 23/23 [==============================] - 1s 23ms/step - loss: 0.3622 - mae: 0.3622 - val_loss: 0.7997 - val_mae: 0.7997
# =====fold 1=======
# train shape (8160, 1878) test shape (4080, 1878)
# Epoch 1/500
# 45/45 [==============================] - 1s 21ms/step - loss: 1.0076 - mae: 1.0076 - val_loss: 0.8866 - val_mae: 0.8866
# Epoch 2/500
# 45/45 [==============================] - 1s 18ms/step - loss: 0.8504 - mae: 0.8504 - val_loss: 0.7734 - val_mae: 0.7734
# Epoch 3/500
# 45/45 [==============================] - 1s 18ms/step - loss: 0.7806 - mae: 0.7806 - val_loss: 0.7501 - val_mae: 0.7501
# Epoch 4/500
# 45/45 [==============================] - 1s 18ms/step - loss: 0.7292 - mae: 0.7292 - val_loss: 0.7883 - val_mae: 0.7883
# Epoch 5/500
# 45/45 [==============================] - 1s 17ms/step - loss: 0.7036 - mae: 0.7036 - val_loss: 0.7260 - val_mae: 0.7260
# Epoch 6/500
# 45/45 [==============================] - 1s 18ms/step - loss: 0.6840 - mae: 0.6840 - val_loss: 0.6875 - val_mae: 0.6875
# Epoch 7/500
# 45/45 [==============================] - 1s 18ms/step - loss: 0.6450 - mae: 0.6450 - val_loss: 0.6762 - val_mae: 0.6762
# Epoch 8/500
# 45/45 [==============================] - 1s 19ms/step - loss: 0.6417 - mae: 0.6417 - val_loss: 0.6707 - val_mae: 0.6707
# Epoch 9/500
# 45/45 [==============================] - 1s 18ms/step - loss: 0.6265 - mae: 0.6265 - val_loss: 0.6596 - val_mae: 0.6596
# Epoch 10/500
# 45/45 [==============================] - 1s 18ms/step - loss: 0.6172 - mae: 0.6172 - val_loss: 0.6907 - val_mae: 0.6907
# Epoch 11/500
# 45/45 [==============================] - 1s 18ms/step - loss: 0.5964 - mae: 0.5964 - val_loss: 0.6627 - val_mae: 0.6627
# Epoch 12/500
# 45/45 [==============================] - 1s 18ms/step - loss: 0.6059 - mae: 0.6059 - val_loss: 0.6546 - val_mae: 0.6546
# Epoch 13/500
# 45/45 [==============================] - 1s 17ms/step - loss: 0.5998 - mae: 0.5998 - val_loss: 0.6733 - val_mae: 0.6733
# Epoch 14/500
# 45/45 [==============================] - 1s 18ms/step - loss: 0.5936 - mae: 0.5936 - val_loss: 0.6997 - val_mae: 0.6997
# Epoch 15/500
# 45/45 [==============================] - 1s 18ms/step - loss: 0.5767 - mae: 0.5767 - val_loss: 0.6857 - val_mae: 0.6857
# Epoch 16/500
# 45/45 [==============================] - 1s 18ms/step - loss: 0.5699 - mae: 0.5699 - val_loss: 0.6875 - val_mae: 0.6875
# Epoch 17/500
# 45/45 [==============================] - 1s 17ms/step - loss: 0.5730 - mae: 0.5730 - val_loss: 0.6809 - val_mae: 0.6809
# Epoch 18/500
# 45/45 [==============================] - 1s 18ms/step - loss: 0.5590 - mae: 0.5590 - val_loss: 0.6668 - val_mae: 0.6668
# Epoch 19/500
# 45/45 [==============================] - 1s 19ms/step - loss: 0.5627 - mae: 0.5627 - val_loss: 0.6996 - val_mae: 0.6996
# Epoch 20/500
# 45/45 [==============================] - 1s 18ms/step - loss: 0.5801 - mae: 0.5801 - val_loss: 0.6555 - val_mae: 0.6555
# Epoch 21/500
# 45/45 [==============================] - 1s 17ms/step - loss: 0.5680 - mae: 0.5680 - val_loss: 0.6477 - val_mae: 0.6477
# Epoch 22/500
# 45/45 [==============================] - 1s 19ms/step - loss: 0.5472 - mae: 0.5472 - val_loss: 0.6667 - val_mae: 0.6667
# Epoch 23/500
# 45/45 [==============================] - 1s 18ms/step - loss: 0.5528 - mae: 0.5528 - val_loss: 0.6861 - val_mae: 0.6861
# Epoch 24/500
# 45/45 [==============================] - 1s 18ms/step - loss: 0.5468 - mae: 0.5468 - val_loss: 0.6630 - val_mae: 0.6630
# Epoch 25/500
# 45/45 [==============================] - 1s 17ms/step - loss: 0.5461 - mae: 0.5461 - val_loss: 0.6665 - val_mae: 0.6665
# Epoch 26/500
# 45/45 [==============================] - 1s 17ms/step - loss: 0.5411 - mae: 0.5411 - val_loss: 0.6978 - val_mae: 0.6978
# Epoch 27/500
# 45/45 [==============================] - 1s 18ms/step - loss: 0.5435 - mae: 0.5435 - val_loss: 0.6928 - val_mae: 0.6928
# Epoch 28/500
# 45/45 [==============================] - 1s 18ms/step - loss: 0.5430 - mae: 0.5430 - val_loss: 0.6582 - val_mae: 0.6582
# Epoch 29/500
# 45/45 [==============================] - 1s 18ms/step - loss: 0.5444 - mae: 0.5444 - val_loss: 0.6714 - val_mae: 0.6714
# Epoch 30/500
# 45/45 [==============================] - 1s 18ms/step - loss: 0.5467 - mae: 0.5467 - val_loss: 0.6657 - val_mae: 0.6657
# Epoch 31/500
# 45/45 [==============================] - 1s 18ms/step - loss: 0.5362 - mae: 0.5362 - val_loss: 0.7012 - val_mae: 0.7012
# Epoch 32/500
# 45/45 [==============================] - 1s 19ms/step - loss: 0.5317 - mae: 0.5317 - val_loss: 0.6756 - val_mae: 0.6756
# Epoch 33/500
# 45/45 [==============================] - 1s 17ms/step - loss: 0.5437 - mae: 0.5437 - val_loss: 0.6776 - val_mae: 0.6776
# Epoch 34/500
# 45/45 [==============================] - 1s 17ms/step - loss: 0.5205 - mae: 0.5205 - val_loss: 0.6638 - val_mae: 0.6638
# Epoch 35/500
# 45/45 [==============================] - 1s 18ms/step - loss: 0.5353 - mae: 0.5353 - val_loss: 0.6919 - val_mae: 0.6919
# Epoch 36/500
# 45/45 [==============================] - 1s 18ms/step - loss: 0.5159 - mae: 0.5159 - val_loss: 0.7126 - val_mae: 0.7126
# Epoch 37/500
# 45/45 [==============================] - 1s 19ms/step - loss: 0.5350 - mae: 0.5350 - val_loss: 0.7280 - val_mae: 0.7280
# Epoch 38/500
# 45/45 [==============================] - 1s 17ms/step - loss: 0.5247 - mae: 0.5247 - val_loss: 0.6747 - val_mae: 0.6747
# Epoch 39/500
# 45/45 [==============================] - 1s 18ms/step - loss: 0.5139 - mae: 0.5139 - val_loss: 0.6917 - val_mae: 0.6917
# Epoch 40/500
# 45/45 [==============================] - 1s 18ms/step - loss: 0.5092 - mae: 0.5092 - val_loss: 0.6936 - val_mae: 0.6936
# Epoch 41/500
# 45/45 [==============================] - 1s 18ms/step - loss: 0.5103 - mae: 0.5103 - val_loss: 0.6743 - val_mae: 0.6743
# Epoch 42/500
# 45/45 [==============================] - 1s 18ms/step - loss: 0.5089 - mae: 0.5089 - val_loss: 0.6866 - val_mae: 0.6866
# Epoch 43/500
# 45/45 [==============================] - 1s 18ms/step - loss: 0.5024 - mae: 0.5024 - val_loss: 0.6705 - val_mae: 0.6705
# Epoch 44/500
# 45/45 [==============================] - 1s 18ms/step - loss: 0.5016 - mae: 0.5016 - val_loss: 0.6853 - val_mae: 0.6853
# Epoch 45/500
# 45/45 [==============================] - 1s 18ms/step - loss: 0.5048 - mae: 0.5048 - val_loss: 0.6754 - val_mae: 0.6754
# Epoch 46/500
# 45/45 [==============================] - 1s 18ms/step - loss: 0.5011 - mae: 0.5011 - val_loss: 0.6556 - val_mae: 0.6556
# Epoch 47/500
# 45/45 [==============================] - 1s 18ms/step - loss: 0.5088 - mae: 0.5088 - val_loss: 0.6740 - val_mae: 0.6740
# Epoch 48/500
# 45/45 [==============================] - 1s 19ms/step - loss: 0.5065 - mae: 0.5065 - val_loss: 0.6698 - val_mae: 0.6698
# Epoch 49/500
# 45/45 [==============================] - 1s 18ms/step - loss: 0.4948 - mae: 0.4948 - val_loss: 0.6807 - val_mae: 0.6807
# Epoch 50/500
# 45/45 [==============================] - 1s 18ms/step - loss: 0.4868 - mae: 0.4868 - val_loss: 0.6682 - val_mae: 0.6682
# Epoch 51/500
# 45/45 [==============================] - 1s 18ms/step - loss: 0.5046 - mae: 0.5046 - val_loss: 0.6725 - val_mae: 0.6725
# Epoch 52/500
# 45/45 [==============================] - 1s 18ms/step - loss: 0.5030 - mae: 0.5030 - val_loss: 0.7411 - val_mae: 0.7411
# Epoch 53/500
# 45/45 [==============================] - 1s 18ms/step - loss: 0.5011 - mae: 0.5011 - val_loss: 0.6778 - val_mae: 0.6778
# Epoch 54/500
# 45/45 [==============================] - 1s 18ms/step - loss: 0.4982 - mae: 0.4982 - val_loss: 0.7044 - val_mae: 0.7044
# Epoch 55/500
# 45/45 [==============================] - 1s 18ms/step - loss: 0.4882 - mae: 0.4882 - val_loss: 0.7092 - val_mae: 0.7092
# Epoch 56/500
# 45/45 [==============================] - 1s 19ms/step - loss: 0.5000 - mae: 0.5000 - val_loss: 0.6799 - val_mae: 0.6799
# Epoch 57/500
# 45/45 [==============================] - 1s 18ms/step - loss: 0.4889 - mae: 0.4889 - val_loss: 0.7158 - val_mae: 0.7158
# Epoch 58/500
# 45/45 [==============================] - 1s 18ms/step - loss: 0.4857 - mae: 0.4857 - val_loss: 0.7069 - val_mae: 0.7069
# Epoch 59/500
# 45/45 [==============================] - 1s 18ms/step - loss: 0.4906 - mae: 0.4906 - val_loss: 0.6942 - val_mae: 0.6942
# Epoch 60/500
# 45/45 [==============================] - 1s 18ms/step - loss: 0.4841 - mae: 0.4841 - val_loss: 0.6868 - val_mae: 0.6868
# Epoch 61/500
# 45/45 [==============================] - 1s 19ms/step - loss: 0.4827 - mae: 0.4827 - val_loss: 0.7265 - val_mae: 0.7265
# Epoch 62/500
# 45/45 [==============================] - 1s 18ms/step - loss: 0.
500
# 45/45 [==============================] - 1s 18ms/step - loss: 0.4406 - mae: 0.4406 - val_loss: 0.6939 - val_mae: 0.6939
# Epoch 118/500
# 45/45 [==============================] - 1s 19ms/step - loss: 0.4395 - mae: 0.4395 - val_loss: 0.6805 - val_mae: 0.6805
# Epoch 119/500
# 45/45 [==============================] - 1s 18ms/step - loss: 0.4336 - mae: 0.4336 - val_loss: 0.6795 - val_mae: 0.6795
# Epoch 120/500
# 45/45 [==============================] - 1s 18ms/step - loss: 0.4282 - mae: 0.4282 - val_loss: 0.7069 - val_mae: 0.7069
# Epoch 121/500
# 45/45 [==============================] - 1s 19ms/step - loss: 0.4349 - mae: 0.4349 - val_loss: 0.6717 - val_mae: 0.6717
#  fold_0 mae: 3.76509425174619
#  fold_1 mae: 3.612536871742123
# mean: 3.6888155617441565

# %%
__df_test = _df_test.copy()
__df_test["pollen_tokyo"] = tokyo_prediction
plt.figure(figsize=(20, 10))
ax = sns.lineplot(data=_df[_df.year==2020], x="datetime_dt", y="pollen_tokyo")
ax = sns.lineplot(data=__df_test, x="datetime_dt", y="pollen_tokyo")

# %% [markdown]
# # chiba pred

# %%
unused_cols = [col for col in _df.columns if ("one_hot" in col)]

# %%
chiba_prediction, scores = train_keras(
   _df.copy(), _df_test, target_label="pollen_chiba", plot=True, qth=q_cb
)

for i, score in enumerate(scores):
    print(f" fold_{i} mae: {score}")
print(f"mean: {np.mean(scores)}")


chiba_score_mlp = np.mean(scores)
# Out:
# =========pollen_chiba==========
# qth = 20
# =====fold 0=======
# train shape (4080, 1878) test shape (4080, 1878)
# Epoch 1/500
# 24/24 [==============================] - 1s 29ms/step - loss: 1.0511 - mae: 1.0511 - val_loss: 0.9352 - val_mae: 0.9352
# Epoch 2/500
# 24/24 [==============================] - 0s 21ms/step - loss: 0.9122 - mae: 0.9122 - val_loss: 0.9011 - val_mae: 0.9011
# Epoch 3/500
# 24/24 [==============================] - 0s 21ms/step - loss: 0.8472 - mae: 0.8472 - val_loss: 0.8295 - val_mae: 0.8295
# Epoch 4/500
# 24/24 [==============================] - 0s 20ms/step - loss: 0.8108 - mae: 0.8108 - val_loss: 0.8339 - val_mae: 0.8339
# Epoch 5/500
# 24/24 [==============================] - 1s 22ms/step - loss: 0.7667 - mae: 0.7667 - val_loss: 0.8149 - val_mae: 0.8149
# Epoch 6/500
# 24/24 [==============================] - 0s 20ms/step - loss: 0.7630 - mae: 0.7630 - val_loss: 0.8059 - val_mae: 0.8059
# Epoch 7/500
# 24/24 [==============================] - 0s 20ms/step - loss: 0.7381 - mae: 0.7381 - val_loss: 0.7993 - val_mae: 0.7993
# Epoch 8/500
# 24/24 [==============================] - 0s 21ms/step - loss: 0.7315 - mae: 0.7315 - val_loss: 0.8092 - val_mae: 0.8092
# Epoch 9/500
# 24/24 [==============================] - 1s 21ms/step - loss: 0.7436 - mae: 0.7436 - val_loss: 0.8660 - val_mae: 0.8660
# Epoch 10/500
# 24/24 [==============================] - 0s 20ms/step - loss: 0.7375 - mae: 0.7375 - val_loss: 0.7639 - val_mae: 0.7639
# Epoch 11/500
# 24/24 [==============================] - 0s 20ms/step - loss: 0.6934 - mae: 0.6934 - val_loss: 0.7642 - val_mae: 0.7642
# Epoch 12/500
# 24/24 [==============================] - 0s 21ms/step - loss: 0.7088 - mae: 0.7088 - val_loss: 0.8055 - val_mae: 0.8055
# Epoch 13/500
# 24/24 [==============================] - 1s 22ms/step - loss: 0.6961 - mae: 0.6961 - val_loss: 0.7764 - val_mae: 0.7764
# Epoch 14/500
# 24/24 [==============================] - 0s 20ms/step - loss: 0.6632 - mae: 0.6632 - val_loss: 0.7870 - val_mae: 0.7870
# Epoch 15/500
# 24/24 [==============================] - 0s 20ms/step - loss: 0.7258 - mae: 0.7258 - val_loss: 0.7589 - val_mae: 0.7589
# Epoch 16/500
# 24/24 [==============================] - 0s 21ms/step - loss: 0.7289 - mae: 0.7289 - val_loss: 0.7893 - val_mae: 0.7893
# Epoch 17/500
# 24/24 [==============================] - 0s 20ms/step - loss: 0.6520 - mae: 0.6520 - val_loss: 0.8229 - val_mae: 0.8229
# Epoch 18/500
# 24/24 [==============================] - 1s 21ms/step - loss: 0.6530 - mae: 0.6530 - val_loss: 0.7760 - val_mae: 0.7760
# Epoch 19/500
# 24/24 [==============================] - 0s 20ms/step - loss: 0.6424 - mae: 0.6424 - val_loss: 0.7906 - val_mae: 0.7906
# Epoch 20/500
# 24/24 [==============================] - 0s 20ms/step - loss: 0.6386 - mae: 0.6386 - val_loss: 0.8214 - val_mae: 0.8214
# Epoch 21/500
# 24/24 [==============================] - 0s 20ms/step - loss: 0.6477 - mae: 0.6477 - val_loss: 0.8087 - val_mae: 0.8087
# Epoch 22/500
# 24/24 [==============================] - 1s 25ms/step - loss: 0.6517 - mae: 0.6517 - val_loss: 0.7737 - val_mae: 0.7737
# Epoch 23/500
# 24/24 [==============================] - 0s 20ms/step - loss: 0.6492 - mae: 0.6492 - val_loss: 0.8163 - val_mae: 0.8163
# Epoch 24/500
# 24/24 [==============================] - 0s 20ms/step - loss: 0.6547 - mae: 0.6547 - val_loss: 0.7746 - val_mae: 0.7746
# Epoch 25/500
# 24/24 [==============================] - 0s 20ms/step - loss: 0.6406 - mae: 0.6406 - val_loss: 0.8010 - val_mae: 0.8010
# Epoch 26/500
# 24/24 [==============================] - 1s 23ms/step - loss: 0.6367 - mae: 0.6367 - val_loss: 0.8032 - val_mae: 0.8032
# Epoch 27/500
# 24/24 [==============================] - 0s 20ms/step - loss: 0.6174 - mae: 0.6174 - val_loss: 0.7604 - val_mae: 0.7604
# Epoch 28/500
# 24/24 [==============================] - 0s 21ms/step - loss: 0.6181 - mae: 0.6181 - val_loss: 0.8148 - val_mae: 0.8148
# Epoch 29/500
# 24/24 [==============================] - 0s 20ms/step - loss: 0.6228 - mae: 0.6228 - val_loss: 0.8198 - val_mae: 0.8198
# Epoch 30/500
# 24/24 [==============================] - 0s 20ms/step - loss: 0.6182 - mae: 0.6182 - val_loss: 0.7938 - val_mae: 0.7938
# Epoch 31/500
# 24/24 [==============================] - 1s 22ms/step - loss: 0.5999 - mae: 0.5999 - val_loss: 0.7795 - val_mae: 0.7795
# Epoch 32/500
# 24/24 [==============================] - 0s 21ms/step - loss: 0.6241 - mae: 0.6241 - val_loss: 0.8227 - val_mae: 0.8227
# Epoch 33/500
# 24/24 [==============================] - 0s 20ms/step - loss: 0.6147 - mae: 0.6147 - val_loss: 0.7764 - val_mae: 0.7764
# Epoch 34/500
# 24/24 [==============================] - 0s 20ms/step - loss: 0.6052 - mae: 0.6052 - val_loss: 0.8108 - val_mae: 0.8108
# Epoch 35/500
# 24/24 [==============================] - 1s 21ms/step - loss: 0.6128 - mae: 0.6128 - val_loss: 0.8066 - val_mae: 0.8066
# Epoch 36/500
# 24/24 [==============================] - 0s 21ms/step - loss: 0.5981 - mae: 0.5981 - val_loss: 0.7953 - val_mae: 0.7953
# Epoch 37/500
# 24/24 [==============================] - 0s 20ms/step - loss: 0.5997 - mae: 0.5997 - val_loss: 0.8004 - val_mae: 0.8004
# Epoch 38/500
# 24/24 [==============================] - 0s 20ms/step - loss: 0.6104 - mae: 0.6104 - val_loss: 0.8010 - val_mae: 0.8010
# Epoch 39/500
# 24/24 [==============================] - 1s 21ms/step - loss: 0.6086 - mae: 0.6086 - val_loss: 0.8248 - val_mae: 0.8248
# Epoch 40/500
# 24/24 [==============================] - 0s 20ms/step - loss: 0.6145 - mae: 0.6145 - val_loss: 0.8462 - val_mae: 0.8462
# Epoch 41/500
# 24/24 [==============================] - 0s 20ms/step - loss: 0.5984 - mae: 0.5984 - val_loss: 0.7788 - val_mae: 0.7788
# Epoch 42/500
# 24/24 [==============================] - 0s 21ms/step - loss: 0.5958 - mae: 0.5958 - val_loss: 0.8213 - val_mae: 0.8213
# Epoch 43/500
# 24/24 [==============================] - 0s 21ms/step - loss: 0.6186 - mae: 0.6186 - val_loss: 0.8156 - val_mae: 0.8156
# Epoch 44/500
# 24/24 [==============================] - 1s 24ms/step - loss: 0.5965 - mae: 0.5965 - val_loss: 0.7929 - val_mae: 0.7929
# Epoch 45/500
# 24/24 [==============================] - 0s 20ms/step - loss: 0.5968 - mae: 0.5968 - val_loss: 0.7843 - val_mae: 0.7843
# Epoch 46/500
# 24/24 [==============================] - 0s 21ms/step - loss: 0.6015 - mae: 0.6015 - val_loss: 0.7921 - val_mae: 0.7921
# Epoch 47/500
# 24/24 [==============================] - 0s 20ms/step - loss: 0.6047 - mae: 0.6047 - val_loss: 0.7879 - val_mae: 0.7879
# Epoch 48/500
# 24/24 [==============================] - 1s 22ms/step - loss: 0
500
# 24/24 [==============================] - 1s 22ms/step - loss: 0.5521 - mae: 0.5521 - val_loss: 0.8268 - val_mae: 0.8268
# Epoch 82/500
# 24/24 [==============================] - 0s 20ms/step - loss: 0.5464 - mae: 0.5464 - val_loss: 0.8154 - val_mae: 0.8154
# Epoch 83/500
# 24/24 [==============================] - 0s 21ms/step - loss: 0.5520 - mae: 0.5520 - val_loss: 0.7817 - val_mae: 0.7817
# Epoch 84/500
# 24/24 [==============================] - 0s 20ms/step - loss: 0.5438 - mae: 0.5438 - val_loss: 0.8231 - val_mae: 0.8231
# Epoch 85/500
# 24/24 [==============================] - 0s 21ms/step - loss: 0.5486 - mae: 0.5486 - val_loss: 0.7845 - val_mae: 0.7845
# Epoch 86/500
# 24/24 [==============================] - 1s 22ms/step - loss: 0.5592 - mae: 0.5592 - val_loss: 0.8013 - val_mae: 0.8013
# Epoch 87/500
# 24/24 [==============================] - 0s 21ms/step - loss: 0.5401 - mae: 0.5401 - val_loss: 0.8221 - val_mae: 0.8221
# Epoch 88/500
# 24/24 [==============================] - 0s 20ms/step - loss: 0.5610 - mae: 0.5610 - val_loss: 0.7931 - val_mae: 0.7931
# Epoch 89/500
# 24/24 [==============================] - 0s 21ms/step - loss: 0.5900 - mae: 0.5900 - val_loss: 0.8297 - val_mae: 0.8297
# Epoch 90/500
# 24/24 [==============================] - 1s 25ms/step - loss: 0.5481 - mae: 0.5481 - val_loss: 0.7436 - val_mae: 0.7436
# Epoch 91/500
# 24/24 [==============================] - 0s 21ms/step - loss: 0.5471 - mae: 0.5471 - val_loss: 0.7634 - val_mae: 0.7634
# Epoch 92/500
# 24/24 [==============================] - 0s 20ms/step - loss: 0.5394 - mae: 0.5394 - val_loss: 0.8176 - val_mae: 0.8176
# Epoch 93/500
# 24/24 [==============================] - 0s 21ms/step - loss: 0.5609 - mae: 0.5609 - val_loss: 0.8292 - val_mae: 0.8292
# Epoch 94/500
# 24/24 [==============================] - 1s 22ms/step - loss: 0.5631 - mae: 0.5631 - val_loss: 0.8327 - val_mae: 0.8327
# Epoch 95/500
# 24/24 [==============================] - 1s 21ms/step - loss: 0.5499 - mae: 0.5499 - val_loss: 0.8016 - val_mae: 0.8016
# Epoch 96/500
# 24/24 [==============================] - 0s 20ms/step - loss: 0.5397 - mae: 0.5397 - val_loss: 0.8067 - val_mae: 0.8067
# Epoch 97/500
# 24/24 [==============================] - 0s 21ms/step - loss: 0.5475 - mae: 0.5475 - val_loss: 0.8080 - val_mae: 0.8080
# Epoch 98/500
# 24/24 [==============================] - 0s 21ms/step - loss: 0.5328 - mae: 0.5328 - val_loss: 0.7760 - val_mae: 0.7760
# Epoch 99/500
# 24/24 [==============================] - 1s 24ms/step - loss: 0.5329 - mae: 0.5329 - val_loss: 0.7890 - val_mae: 0.7890
# Epoch 100/500
# 24/24 [==============================] - 0s 20ms/step - loss: 0.5415 - mae: 0.5415 - val_loss: 0.8378 - val_mae: 0.8378
# Epoch 101/500
# 24/24 [==============================] - 0s 21ms/step - loss: 0.5399 - mae: 0.5399 - val_loss: 0.7821 - val_mae: 0.7821
# Epoch 102/500
# 24/24 [==============================] - 1s 21ms/step - loss: 0.5382 - mae: 0.5382 - val_loss: 0.7471 - val_mae: 0.7471
# Epoch 103/500
# 24/24 [==============================] - 1s 22ms/step - loss: 0.5774 - mae: 0.5774 - val_loss: 0.8310 - val_mae: 0.8310
# Epoch 104/500
# 24/24 [==============================] - 0s 21ms/step - loss: 0.5546 - mae: 0.5546 - val_loss: 0.7966 - val_mae: 0.7966
# Epoch 105/500
# 24/24 [==============================] - 0s 21ms/step - loss: 0.5639 - mae: 0.5639 - val_loss: 0.7943 - val_mae: 0.7943
# Epoch 106/500
# 24/24 [==============================] - 0s 21ms/step - loss: 0.5508 - mae: 0.5508 - val_loss: 0.7716 - val_mae: 0.7716
# Epoch 107/500
# 24/24 [==============================] - 1s 22ms/step - loss: 0.5424 - mae: 0.5424 - val_loss: 0.7896 - val_mae: 0.7896
# Epoch 108/500
# 24/24 [==============================] - 0s 21ms/step - loss: 0.5316 - mae: 0.5316 - val_loss: 0.8062 - val_mae: 0.8062
# Epoch 109/500
# 24/24 [==============================] - 1s 21ms/step - loss: 0.5305 - mae: 0.5305 - val_loss: 0.7646 - val_mae: 0.7646
# Epoch 110/500
# 24/24 [==============================] - 1s 24ms/step - loss: 0.5349 - mae: 0.5349 - val_loss: 0.8284 - val_mae: 0.8284
# Epoch 111/500
# 24/24 [==============================] - 1s 23ms/step - loss: 0.5456 - mae: 0.5456 - val_loss: 0.8212 - val_mae: 0.8212
# Epoch 112/500
# 24/24 [==============================] - 0s 21ms/step - loss: 0.5328 - mae: 0.5328 - val_loss: 0.7765 - val_mae: 0.7765
# Epoch 113/500
# 24/24 [==============================] - 0s 21ms/step - loss: 0.5424 - mae: 0.5424 - val_loss: 0.7961 - val_mae: 0.7961
# Epoch 114/500
# 24/24 [==============================] - 0s 20ms/step - loss: 0.5451 - mae: 0.5451 - val_loss: 0.8219 - val_mae: 0.8219
# Epoch 115/500
# 24/24 [==============================] - 1s 23ms/step - loss: 0.5476 - mae: 0.5476 - val_loss: 0.8147 - val_mae: 0.8147
# Epoch 116/500
# 24/24 [==============================] - 0s 20ms/step - loss: 0.5232 - mae: 0.5232 - val_loss: 0.8058 - val_mae: 0.8058
# Epoch 117/500
# 24/24 [==============================] - 0s 21ms/step - loss: 0.5190 - mae: 0.5190 - val_loss: 0.8103 - val_mae: 0.8103
# Epoch 118/500
# 24/24 [==============================] - 0s 20ms/step - loss: 0.5382 - mae: 0.5382 - val_loss: 0.8110 - val_mae: 0.8110
# Epoch 119/500
# 24/24 [==============================] - 1s 23ms/step - loss: 0.5254 - mae: 0.5254 - val_loss: 0.8055 - val_mae: 0.8055
# Epoch 120/500
# 24/24 [==============================] - 1s 21ms/step - loss: 0.5395 - mae: 0.5395 - val_loss: 0.8188 - val_mae: 0.8188
# Epoch 121/500
# 24/24 [==============================] - 0s 21ms/step - loss: 0.5235 - mae: 0.5235 - val_loss: 0.8248 - val_mae: 0.8248
# Epoch 122/500
# 24/24 [==============================] - 0s 21ms/step - loss: 0.5139 - mae: 0.5139 - val_loss: 0.7738 - val_mae: 0.7738
# Epoch 123/500
# 24/24 [==============================] - 1s 22ms/step - loss: 0.5218 - mae: 0.5218 - val_loss: 0.7815 - val_mae: 0.7815
# Epoch 124/500
# 24/24 [==============================] - 1s 21ms/step - loss: 0.5125 - mae: 0.5125 - val_loss: 0.7773 - val_mae: 0.7773
# Epoch 125/500
# 24/24 [==============================] - 1s 21ms/step - loss: 0.5082 - mae: 0.5082 - val_loss: 0.7754 - val_mae: 0.7754
# Epoch 126/500
# 24/24 [==============================] - 1s 24ms/step - loss: 0.5155 - mae: 0.5155 - val_loss: 0.7481 - val_mae: 0.7481
# Epoch 127/500
# 24/24 [==============================] - 1s 21ms/step - loss: 0.5264 - mae: 0.5264 - val_loss: 0.7992 - val_mae: 0.7992
# Epoch 128/500
# 24/24 [==============================] - 1s 22ms/step - loss: 0.5317 - mae: 0.5317 - val_loss: 0.8323 - val_mae: 0.8323
# Epoch 129/500
# 24/24 [==============================] - 1s 21ms/step - loss: 0.5330 - mae: 0.5330 - val_loss: 0.8147 - val_mae: 0.8147
# Epoch 130/500
# 24/24 [==============================] - 0s 21ms/step - loss: 0.5109 - mae: 0.5109 - val_loss: 0.7937 - val_mae: 0.7937
# Epoch 131/500
# 24/24 [==============================] - 0s 21ms/step - loss: 0.5334 - mae: 0.5334 - val_loss: 0.7809 - val_mae: 0.7809
# Epoch 132/500
# 24/24 [==============================] - 1s 25ms/step - loss: 0.5224 - mae: 0.5224 - val_loss: 0.7832 - val_mae: 0.7832
# Epoch 133/500
# 24/24 [==============================] - 0s 21ms/step - loss: 0.5558 - mae: 0.5558 - val_loss: 0.7801 - val_mae: 0.7801
# Epoch 134/500
# 24/24 [==============================] - 0s 21ms/step - loss: 0.5301 - mae: 0.5301 - val_loss: 0.7613 - val_mae: 0.7613
# Epoch 135/500
# 24/24 [==============================] - 0s 21ms/step - loss: 0.5239 - mae: 0.5239 - val_loss: 0.7435 - val_mae: 0.7435
# Epoch 136/500
# 24/24 [==============================] - 1s 23ms/step - loss: 0.5333 - mae: 0.5333 - val_loss: 0.7608 - val_mae: 0.7608
# Epoch 137/500
# 24/24 [==============================] - 0s 21ms/step - loss: 0.5273 - mae: 0.5273 - val_loss: 0.7670 - val_mae: 0.7670
# Epoch 138/500
# 24/24 [==============================] - 1s 24ms/step - loss: 0.5136 - mae: 0.5136 - val_loss: 0.8189 - val_mae: 0.8189
# Epoch 139/500
# 24/24 [==============================] - 1s 21ms/step - loss: 0.5257 - mae: 0.5257 - val_loss: 0.8131 - val_mae: 0.8131
# Epoch 140/500
# 24/24 [==============================] - 1s 22ms/step - loss: 0.5310 - mae: 0.5310 - val_loss: 0.7614 - val_mae: 0.7614
# Epoch 141/500
# 24/24 [==============================] - 0s 20ms/step - loss: 0.5110 - mae: 0.5110 - val_loss: 0.7556 - val_mae: 0.7556
# Epoch 142/500
# 24/24 [==============================] - 1s 21ms/step - loss: 0.5152 - mae: 0.5152 - val_loss: 0.7941 - val_mae: 0.7941
# Epoch 143/500
# 24/24 [==============================] - 1s 21ms/step - loss: 0.5064 - mae: 0.5064 - val_loss: 0.8098 - val_mae: 0.8098
# Epoch 144/500
# 24/24 [==============================] - 1s 22ms/step - loss: 0.4990 - mae: 0.4990 - val_loss: 0.7904 - val_mae: 0.7904
# Epoch 145/500
# 24/24 [==============================] - 1s 21ms/step - loss: 0.5286 - mae: 0.5286 - val_loss: 0.7926 - val_mae: 0.7926
# Epoch 146/500
# 24/24 [==============================] - 0s 21ms/step - loss: 0.5162 - mae: 0.5162 - val_loss: 0.7687 - val_mae: 0.7687
# Epoch 147/500
# 24/24 [==============================] - 0s 21ms/step - loss: 0.5124 - mae: 0.5124 - val_loss: 0.7831 - val_mae: 0.7831
# Epoch 148/500
# 24/24 [==============================] - 1s 23ms/step - loss: 0.5037 - mae: 0.5037 - val_loss: 0.8138 - val_mae: 0.8138
# Epoch 149/500
# 24/24 [==============================] - 1s 24ms/step - loss: 0.4933 - mae: 0.4933 - val_loss: 0.7931 - val_mae: 0.7931
# Epoch 150/500
# 24/24 [==============================] - 1s 21ms/step - loss: 0.5016 - mae: 0.5016 - val_loss: 0.7831 - val_mae: 0.7831
# Epoch 151/500
# 24/24 [==============================] - 0s 20ms/step - loss: 0.4754 - mae: 0.4754 - val_loss: 0.8105 - val_mae: 0.8105
# Epoch 152/500
# 24/24 [==============================] - 1s 22ms/step - loss: 0.5015 - mae: 0.5015 - val_loss: 0.7832 - val_mae: 0.7832
# Epoch 153/500
# 24/24 [==============================] - 0s 21ms/step - loss: 0.5070 - mae: 0.5070 - val_loss: 0.7552 - val_mae: 0.7552
# Epoch 154/500
# 24/24 [==============================] - 1s 21ms/step - loss: 0.4939 - mae: 0.4939 - val_loss: 0.7704 - val_mae: 0.7704
# Epoch 155/500
# 24/24 [==============================] - 1s 21ms/step - loss: 0.5070 - mae: 0.5070 - val_loss: 0.7975 - val_mae: 0.7975
# Epoch 156/500
# 24/24 [==============================] - 1s 22ms/step - loss: 0.4862 - mae: 0.4862 - val_loss: 0.8060 - val_mae: 0.8060
# Epoch 157/500
# 24/24 [==============================] - 0s 21ms/step - loss: 0.5117 - mae: 0.5117 - val_loss: 0.8117 - val_mae: 0.8117
# Epoch 158/500
# 24/24 [==============================] - 1s 21ms/step - loss: 0.5290 - mae: 0.5290 - val_loss: 0.8068 - val_mae: 0.8068
# Epoch 159/500
# 24/24 [==============================] - 0s 21ms/step - loss: 0.4990 - mae: 0.4990 - val_loss: 0.8114 - val_mae: 0.8114
# Epoch 160/500
# 24/24 [==============================] - 1s 26ms/step - loss: 0.4880 - mae: 0.4880 - val_loss: 0.7681 - val_mae: 0.7681
# Epoch 161/500
# 24/24 [==============================] - 0s 21ms/step - loss: 0.4879 - mae: 0.4879 - val_loss: 0.8036 - val_mae: 0.8036
# Epoch 162/500
# 24/24 [==============================] - 1s 21ms/step - loss: 0.4860 - mae: 0.4860 - val_loss: 0.8009 - val_mae: 0.8009
# Epoch 163/500
# 24/24 [==============================] - 1s 21ms/step - loss: 0.5010 - mae: 0.5010 - val_loss: 0.8053 - val_mae: 0.8053
# Epoch 164/500
# 24/24 [==============================] - 1s 23ms/step - loss: 0.5028 - mae: 0.5028 - val_loss: 0.8078 - val_mae: 0.8078
# Epoch 165/500
# 24/24 [==============================] - 1s 21ms/step - loss: 0.5002 - mae: 0.5002 - val_loss: 0.8081 - val_mae: 0.8081
# =====fold 1=======
# train shape (8160, 1878) test shape (4080, 1878)
# Epoch 1/500
# 46/46 [==============================] - 1s 21ms/step - loss: 0.9934 - mae: 0.9934 - val_loss: 0.8287 - val_mae: 0.8287
# Epoch 2/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.8483 - mae: 0.8483 - val_loss: 0.7687 - val_mae: 0.7687
# Epoch 3/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.7933 - mae: 0.7933 - val_loss: 0.7574 - val_mae: 0.7574
# Epoch 4/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.7609 - mae: 0.7609 - val_loss: 0.6855 - val_mae: 0.6855
# Epoch 5/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.7425 - mae: 0.7425 - val_loss: 0.6954 - val_mae: 0.6954
# Epoch 6/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.7220 - mae: 0.7220 - val_loss: 0.7523 - val_mae: 0.7523
# Epoch 7/500
# 46/46 [==============================] - 1s 21ms/step - loss: 0.7217 - mae: 0.7217 - val_loss: 0.6462 - val_mae: 0.6462
# Epoch 8/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.7087 - mae: 0.7087 - val_loss: 0.6642 - val_mae: 0.6642
# Epoch 9/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.6853 - mae: 0.6853 - val_loss: 0.6446 - val_mae: 0.6446
# Epoch 10/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.6754 - mae: 0.6754 - val_loss: 0.7029 - val_mae: 0.7029
# Epoch 11/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.6626 - mae: 0.6626 - val_loss: 0.6393 - val_mae: 0.6393
# Epoch 12/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.6580 - mae: 0.6580 - val_loss: 0.6685 - val_mae: 0.6685
# Epoch 13/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.6505 - mae: 0.6505 - val_loss: 0.6871 - val_mae: 0.6871
# Epoch 14/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.6640 - mae: 0.6640 - val_loss: 0.6834 - val_mae: 0.6834
# Epoch 15/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.6429 - mae: 0.6429 - val_loss: 0.6409 - val_mae: 0.6409
# Epoch 16/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.6497 - mae: 0.6497 - val_loss: 0.6456 - val_mae: 0.6456
# Epoch 17/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.6441 - mae: 0.6441 - val_loss: 0.6550 - val_mae: 0.6550
# Epoch 18/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.6315 - mae: 0.6315 - val_loss: 0.6525 - val_mae: 0.6525
# Epoch 19/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.6488 - mae: 0.6488 - val_loss: 0.6418 - val_mae: 0.6418
# Epoch 20/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.6323 - mae: 0.6323 - val_loss: 0.6539 - val_mae: 0.6539
# Epoch 21/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.6218 - mae: 0.6218 - val_loss: 0.6151 - val_mae: 0.6151
# Epoch 22/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.6202 - mae: 0.6202 - val_loss: 0.6436 - val_mae: 0.6436
# Epoch 23/500
# 46/46 [==============================] - 1s 20ms/step - loss: 0.6153 - mae: 0.6153 - val_loss: 0.6449 - val_mae: 0.6449
# Epoch 24/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.6386 - mae: 0.6386 - val_loss: 0.6120 - val_mae: 0.6120
# Epoch 25/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.6264 - mae: 0.6264 - val_loss: 0.6569 - val_mae: 0.6569
# Epoch 26/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.6315 - mae: 0.6315 - val_loss: 0.6316 - val_mae: 0.6316
# Epoch 27/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.6209 - mae: 0.6209 - val_loss: 0.6327 - val_mae: 0.6327
# Epoch 28/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.6368 - mae: 0.6368 - val_loss: 0.6190 - val_mae: 0.6190
# Epoch 29/500
# 46/46 [==============================] - 1s 21ms/step - loss: 0.6186 - mae: 0.6186 - val_loss: 0.5983 - val_mae: 0.5983
# Epoch 30/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.6129 - mae: 0.6129 - val_loss: 0.6699 - val_mae: 0.6699
# Epoch 31/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.6130 - mae: 0.6130 - val_loss: 0.6493 - val_mae: 0.6493
# Epoch 32/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.6064 - mae: 0.6064 - val_loss: 0.6665 - val_mae: 0.6665
# Epoch 33/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.6101 - mae: 0.6101 - val_loss: 0.6018 - val_mae: 0.6018
# Epoch 34/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.6095 - mae: 0.6095 - val_loss: 0.5960 - val_mae: 0.5960
# Epoch 35/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.6072 - mae: 0.6072 - val_loss: 0.6015 - val_mae: 0.6015
# Epoch 36/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.6118 - mae: 0.6118 - val_loss: 0.6476 - val_mae: 0.6476
# Epoch 37/500
# 46/46 [==============================] - 1s 20ms/step - loss: 0.6001 - mae: 0.6001 - val_loss: 0.6102 - val_mae: 0.6102
# Epoch 38/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.6062 - mae: 0.6062 - val_loss: 0.6238 - val_mae: 0.6238
# Epoch 39/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.5932 - mae: 0.5932 - val_loss: 0.6160 - val_mae: 0.6160
# Epoch 40/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.6012 - mae: 0.6012 - val_loss: 0.6531 - val_mae: 0.6531
# Epoch 41/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.5976 - mae: 0.5976 - val_loss: 0.6191 - val_mae: 0.6191
# Epoch 42/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.6119 - mae: 0.6119 - val_loss: 0.6068 - val_mae: 0.6068
# Epoch 43/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.5891 - mae: 0.5891 - val_loss: 0.6390 - val_mae: 0.6390
# Epoch 44/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.5879 - mae: 0.5879 - val_loss: 0.6409 - val_mae: 0.6409
# Epoch 45/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.5863 - mae: 0.5863 - val_loss: 0.6120 - val_mae: 0.6120
# Epoch 46/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.5952 - mae: 0.5952 - val_loss: 0.6178 - val_mae: 0.6178
# Epoch 47/500
# 46/46 [==============================] - 1s 20ms/step - loss: 0.5962 - mae: 0.5962 - val_loss: 0.6334 - val_mae: 0.6334
# Epoch 48/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.6041 - mae: 0.6041 - val_loss: 0.6390 - val_mae: 0.6390
# Epoch 49/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.6006 - mae: 0.6006 - val_loss: 0.6009 - val_mae: 0.6009
# Epoch 50/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.5822 - mae: 0.5822 - val_loss: 0.5875 - val_mae: 0.5875
# Epoch 51/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.5900 - mae: 0.5900 - val_loss: 0.6301 - val_mae: 0.6301
# Epoch 52/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.5907 - mae: 0.5907 - val_loss: 0.6539 - val_mae: 0.6539
# Epoch 53/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.6123 - mae: 0.6123 - val_loss: 0.7378 - val_mae: 0.7378
# Epoch 54/500
# 46/46 [==============================] - 1s 20ms/step - loss: 0.6204 - mae: 0.6204 - val_loss: 0.6454 - val_mae: 0.6454
# Epoch 55/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.5992 - mae: 0.5992 - val_loss: 0.6543 - val_mae: 0.6543
# Epoch 56/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.6002 - mae: 0.6002 - val_loss: 0.5964 - val_mae: 0.5964
# Epoch 57/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.5923 - mae: 0.5923 - val_loss: 0.6305 - val_mae: 0.6305
# Epoch 58/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.5811 - mae: 0.5811 - val_loss: 0.6297 - val_mae: 0.6297
# Epoch 59/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.5822 - mae: 0.5822 - val_loss: 0.6390 - val_mae: 0.6390
# Epoch 60/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.5746 - mae: 0.5746 - val_loss: 0.6508 - val_mae: 0.6508
# Epoch 61/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.5830 - mae: 0.5830 - val_loss: 0.6282 - val_mae: 0.6282
# Epoch 62/500
# 46/46 [==============================] - 1s 20ms/step - loss: 0.5739 - mae: 0.5739 - val_loss: 0.6919 - val_mae: 0.6919
# Epoch 63/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.
500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.5544 - mae: 0.5544 - val_loss: 0.5989 - val_mae: 0.5989
# Epoch 95/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.5479 - mae: 0.5479 - val_loss: 0.6035 - val_mae: 0.6035
# Epoch 96/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.5445 - mae: 0.5445 - val_loss: 0.5919 - val_mae: 0.5919
# Epoch 97/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.5628 - mae: 0.5628 - val_loss: 0.5880 - val_mae: 0.5880
# Epoch 98/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.5477 - mae: 0.5477 - val_loss: 0.6402 - val_mae: 0.6402
# Epoch 99/500
# 46/46 [==============================] - 1s 20ms/step - loss: 0.5665 - mae: 0.5665 - val_loss: 0.6103 - val_mae: 0.6103
# Epoch 100/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.5524 - mae: 0.5524 - val_loss: 0.6471 - val_mae: 0.6471
# Epoch 101/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.5462 - mae: 0.5462 - val_loss: 0.5923 - val_mae: 0.5923
# Epoch 102/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.5487 - mae: 0.5487 - val_loss: 0.7158 - val_mae: 0.7158
# Epoch 103/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.5490 - mae: 0.5490 - val_loss: 0.6832 - val_mae: 0.6832
# Epoch 104/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.5739 - mae: 0.5739 - val_loss: 0.6306 - val_mae: 0.6306
# Epoch 105/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.5539 - mae: 0.5539 - val_loss: 0.7117 - val_mae: 0.7117
# Epoch 106/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.5564 - mae: 0.5564 - val_loss: 0.6143 - val_mae: 0.6143
# Epoch 107/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.5528 - mae: 0.5528 - val_loss: 0.6121 - val_mae: 0.6121
# Epoch 108/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.5588 - mae: 0.5588 - val_loss: 0.6336 - val_mae: 0.6336
# Epoch 109/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.5452 - mae: 0.5452 - val_loss: 0.6970 - val_mae: 0.6970
# Epoch 110/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.5578 - mae: 0.5578 - val_loss: 0.6387 - val_mae: 0.6387
# Epoch 111/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.5569 - mae: 0.5569 - val_loss: 0.5852 - val_mae: 0.5852
# Epoch 112/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.5353 - mae: 0.5353 - val_loss: 0.6141 - val_mae: 0.6141
# Epoch 113/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.5382 - mae: 0.5382 - val_loss: 0.6184 - val_mae: 0.6184
# Epoch 114/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.5525 - mae: 0.5525 - val_loss: 0.6010 - val_mae: 0.6010
# Epoch 115/500
# 46/46 [==============================] - 1s 20ms/step - loss: 0.5328 - mae: 0.5328 - val_loss: 0.6090 - val_mae: 0.6090
# Epoch 116/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.5416 - mae: 0.5416 - val_loss: 0.6151 - val_mae: 0.6151
# Epoch 117/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.5419 - mae: 0.5419 - val_loss: 0.6790 - val_mae: 0.6790
# Epoch 118/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.5489 - mae: 0.5489 - val_loss: 0.5742 - val_mae: 0.5742
# Epoch 119/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.5541 - mae: 0.5541 - val_loss: 0.6003 - val_mae: 0.6003
# Epoch 120/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.5243 - mae: 0.5243 - val_loss: 0.6119 - val_mae: 0.6119
# Epoch 121/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.5440 - mae: 0.5440 - val_loss: 0.6083 - val_mae: 0.6083
# Epoch 122/500
# 46/46 [==============================] - 1s 20ms/step - loss: 0.5403 - mae: 0.5403 - val_loss: 0.6023 - val_mae: 0.6023
# Epoch 123/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.5535 - mae: 0.5535 - val_loss: 0.5961 - val_mae: 0.5961
# Epoch 124/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.5277 - mae: 0.5277 - val_loss: 0.6171 - val_mae: 0.6171
# Epoch 125/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.
500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.5241 - mae: 0.5241 - val_loss: 0.6275 - val_mae: 0.6275
# Epoch 155/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.5285 - mae: 0.5285 - val_loss: 0.6673 - val_mae: 0.6673
# Epoch 156/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.5278 - mae: 0.5278 - val_loss: 0.6552 - val_mae: 0.6552
# Epoch 157/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.5187 - mae: 0.5187 - val_loss: 0.6487 - val_mae: 0.6487
# Epoch 158/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.5219 - mae: 0.5219 - val_loss: 0.6434 - val_mae: 0.6434
# Epoch 159/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.5325 - mae: 0.5325 - val_loss: 0.6018 - val_mae: 0.6018
# Epoch 160/500
# 46/46 [==============================] - 1s 20ms/step - loss: 0.5175 - mae: 0.5175 - val_loss: 0.6049 - val_mae: 0.6049
# Epoch 161/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.5148 - mae: 0.5148 - val_loss: 0.5810 - val_mae: 0.5810
# Epoch 162/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.5256 - mae: 0.5256 - val_loss: 0.6593 - val_mae: 0.6593
# Epoch 163/500
# 46/46 [==============================] - 1s 20ms/step - loss: 0.5166 - mae: 0.5166 - val_loss: 0.5978 - val_mae: 0.5978
# Epoch 164/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.5173 - mae: 0.5173 - val_loss: 0.6826 - val_mae: 0.6826
# Epoch 165/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.5259 - mae: 0.5259 - val_loss: 0.6807 - val_mae: 0.6807
# Epoch 166/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.5226 - mae: 0.5226 - val_loss: 0.6046 - val_mae: 0.6046
# Epoch 167/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.5299 - mae: 0.5299 - val_loss: 0.6130 - val_mae: 0.6130
# Epoch 168/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.5290 - mae: 0.5290 - val_loss: 0.5978 - val_mae: 0.5978
# Epoch 169/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.5187 - mae: 0.5187 - val_loss: 0.6234 - val_mae: 0.6234
# Epoch 170/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.5282 - mae: 0.5282 - val_loss: 0.6416 - val_mae: 0.6416
# Epoch 171/500
# 46/46 [==============================] - 1s 20ms/step - loss: 0.5199 - mae: 0.5199 - val_loss: 0.6115 - val_mae: 0.6115
# Epoch 172/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.5099 - mae: 0.5099 - val_loss: 0.6501 - val_mae: 0.6501
# Epoch 173/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.5171 - mae: 0.5171 - val_loss: 0.6435 - val_mae: 0.6435
# Epoch 174/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.5255 - mae: 0.5255 - val_loss: 0.6783 - val_mae: 0.6783
# Epoch 175/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.5218 - mae: 0.5218 - val_loss: 0.6064 - val_mae: 0.6064
# Epoch 176/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.5116 - mae: 0.5116 - val_loss: 0.7048 - val_mae: 0.7048
# Epoch 177/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.5092 - mae: 0.5092 - val_loss: 0.6671 - val_mae: 0.6671
# Epoch 178/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.5227 - mae: 0.5227 - val_loss: 0.6470 - val_mae: 0.6470
# Epoch 179/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.5406 - mae: 0.5406 - val_loss: 0.6464 - val_mae: 0.6464
# Epoch 180/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.5174 - mae: 0.5174 - val_loss: 0.6739 - val_mae: 0.6739
# Epoch 181/500
# 46/46 [==============================] - 1s 18ms/step - loss: 0.5225 - mae: 0.5225 - val_loss: 0.6833 - val_mae: 0.6833
# Epoch 182/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.5235 - mae: 0.5235 - val_loss: 0.6555 - val_mae: 0.6555
# Epoch 183/500
# 46/46 [==============================] - 1s 20ms/step - loss: 0.5139 - mae: 0.5139 - val_loss: 0.6310 - val_mae: 0.6310
# Epoch 184/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.5019 - mae: 0.5019 - val_loss: 0.7190 - val_mae: 0.7190
# Epoch 185/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.
500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.4972 - mae: 0.4972 - val_loss: 0.6074 - val_mae: 0.6074
# Epoch 214/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.4974 - mae: 0.4974 - val_loss: 0.6566 - val_mae: 0.6566
# Epoch 215/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.5048 - mae: 0.5048 - val_loss: 0.6132 - val_mae: 0.6132
# Epoch 216/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.5068 - mae: 0.5068 - val_loss: 0.6352 - val_mae: 0.6352
# Epoch 217/500
# 46/46 [==============================] - 1s 20ms/step - loss: 0.5059 - mae: 0.5059 - val_loss: 0.5980 - val_mae: 0.5980
# Epoch 218/500
# 46/46 [==============================] - 1s 19ms/step - loss: 0.4969 - mae: 0.4969 - val_loss: 0.6235 - val_mae: 0.6235
#  fold_0 mae: 4.104735084933067
#  fold_1 mae: 3.795484441159971
# mean: 3.9501097630465187

# %%
df_sub_mlp = _df_test[["datetime"]]
df_sub_mlp.loc[:, "pollen_utsunomiya"] = utsunomiya_prediction
df_sub_mlp.loc[:, "pollen_chiba"] = chiba_prediction
df_sub_mlp.loc[:, "pollen_tokyo"] = tokyo_prediction
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1667: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value

# %%
print("====mlp score====")
utsunomiya_score_mlp, tokyo_score_mlp, chiba_score_mlp, np.mean(
    [utsunomiya_score_mlp, tokyo_score_mlp, chiba_score_mlp]
)
# Out:
# ====mlp score====
# (3.8912999267095945,
#  3.6888155617441565,
#  3.9501097630465187,
#  3.8434084171667564)

# %%
print("==== lgbm score ====")
utsunomiya_score, tokyo_score, chiba_score, np.mean(
    [utsunomiya_score, tokyo_score, chiba_score]
)
# Out:
# ==== lgbm score ====
# (3.301623812879706, 3.4760406943250937, 3.6944679764401718, 3.490710827881657)

# %% [markdown]
# # Emsemble

# %%
cols = ["pollen_tokyo"]
df_final_sub = df_sub.copy()
df_subs = [df_sub_mlp]

# %%
for col in cols:
    for _df in df_subs:        
        df_final_sub[col] += _df[col]
        
    df_final_sub[col] = df_final_sub[col] / (len(df_subs) + 1)

# %%
df_final_sub.to_csv("sub.csv", index=None)

# %%
df_final_sub.head()
# Out:
#      datetime  pollen_utsunomiya  pollen_chiba  pollen_tokyo
# 0  2020040101           3.254020      2.864844      4.576456
# 1  2020040102           2.835438      3.828365      2.642924
# 2  2020040103           2.408286      3.452884      4.650268
# 3  2020040104           1.588979      1.910947      3.629909
# 4  2020040105           2.921656      2.047789      4.107957

# %%
df_sub.head()
# Out:
#      datetime  pollen_utsunomiya  pollen_chiba  pollen_tokyo
# 0  2020040101           3.254020      2.864844      3.716969
# 1  2020040102           2.835438      3.828365      2.979822
# 2  2020040103           2.408286      3.452884      4.342066
# 3  2020040104           1.588979      1.910947      4.863504
# 4  2020040105           2.921656      2.047789      4.164041

# %%
df_sub_mlp.head()
# Out:
#      datetime  pollen_utsunomiya  pollen_chiba  pollen_tokyo
# 0  2020040101           3.647612      2.271482      5.435943
# 1  2020040102           2.827804      1.822823      2.306026
# 2  2020040103           4.149288      1.047481      4.958470
# 3  2020040104           2.038247      0.000297      2.396314
# 4  2020040105           5.217808      0.333046      4.051873
